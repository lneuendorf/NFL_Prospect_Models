# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import arange
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_pinball_loss

# %%
# load data
pd.set_option('display.max_rows', 10000) 
pd.set_option('display.max_columns', 1000)
df = pd.read_excel('~/nfl_dashboard/ml_models/data/wr_data.xlsx')
df.drop(['Clean_Name','NFL_POS','DR','G_Y2','G_Y3','Y1_PPR_Pts','Pts_Y2','Pts_Y3','Y1-Y3_Total_PPR','G_Y1-Y3','Y1-Y3_PPR_PPG'], axis=1, inplace=True)
df.sort_values(by='Draft_Year', ascending=False, inplace=True, ignore_index=True)

# split data
labels_all = df.iloc[:, 0:5]
x_all = df.iloc[:, 5:-2] # all features
y_all = df.iloc[:, -1:] # all y data
train_x = df.iloc[22:, 5:-2] # features with at least 3 nfl years
train_y = df.iloc[22:, -1:] # y data with at least 3 nfl years

# %%
df.head()
# Out:
#             Name          School      Conference  Draft_Year Landing_Team  \
# 0    Jayden Reed  Michigan State  Big Ten (East)        2023          NaN
# 1     Josh Downs  North Carolina   ACC (Coastal)        2023          NaN
# 2  Marcus Rosemy         Georgia      SEC (East)        2023          NaN
# 3      Ajou Ajou         Clemson  ACC (Atlantic)        2023          NaN
# 4   Demond Demas       Texas A&M      SEC (West)        2023          NaN
#
#     DP  Age_In_Draft_Yr  BOA_20%  BOA_30%  Career_YPR  Career_REC/g  \
# 0  167             22.0     18.0     18.0   15.067568      4.625000
# 1   35             22.0     20.0     20.0   13.462963      6.352941
# 2  300             21.0      NaN      NaN   14.181818      1.222222
# 3  300             21.0      NaN      NaN   12.166667      1.500000
# 4  300             22.0      NaN      NaN   15.666667      1.875000
#
#    Career_College_Dominator_Rating  Career_Weighted_Dominator  \
# 0                         0.518508                   0.487391
# 1                         0.531988                   0.574257
# 2                         0.000000                   0.000000
# 3                         0.000000                   0.000000
# 4                         0.109889                   0.128454
#
#    Career_YPTpA_Dominator  Career_Yards_Dominator  First_RecYds/TmPatt  \
# 0                2.571429                0.311098             2.202594
# 1                3.531746                0.401625             3.531746
# 2                0.000000                0.026449                  NaN
# 3                0.000000                0.029376                  NaN
# 4                0.955285                0.093887             0.955285
#
#    Best_RecYds/TmPatt  Last_RecYds/TmPatt  AVG_RecYds/TmPatt  \
# 0            2.571429            2.571429           2.151947
# 1            3.531746            3.531746           3.531746
# 2            0.000000            0.000000                NaN
# 3            0.000000            0.000000                NaN
# 4            0.955285            0.955285           0.955285
#
#    First_RecYds/TmPatt_Above_Conference_AVg  \
# 0                                  0.274091
# 1                                  1.704642
# 2                                       NaN
# 3                                       NaN
# 4                                 -1.124022
#
#    Best_RecYds/TmPatt_Above_Conference_Avg  \
# 0                                 0.602738
# 1                                 1.704642
# 2                                 0.000000
# 3                                 0.000000
# 4                                -1.124022
#
#    Last__RecYds/TmPatt_Above_Conference_Avg  \
# 0                                  0.602738
# 1                                  1.704642
# 2                                  0.000000
# 3                                  0.000000
# 4                                 -1.124022
#
#    AVG__RecYds/TmPatt_Above_Conference_Avg  First_RecYds/TmPatt_Above_AGE_Avg  \
# 0                                 0.189569                           0.594896
# 1                                      NaN                           1.102227
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                          -1.474235
#
#    Best_RecYds/TmPatt_Above_AGE_Avg  Last__RecYds/TmPatt_Above_AGE_Avg  \
# 0                          0.594896                           0.004845
# 1                          1.102227                           1.102227
# 2                          0.000000                           0.000000
# 3                          0.000000                           0.000000
# 4                         -1.474235                          -1.474235
#
#    AVG__RecYds/TmPatt_Above_AGE_Avg  First_RecYds/TmPatt_Above_Experience_Avg  \
# 0                          -0.04932                                  0.594719
# 1                               NaN                                  1.652028
# 2                               NaN                                       NaN
# 3                               NaN                                       NaN
# 4                               NaN                                 -0.381898
#
#    Best_RecYds/TmPatt_Above_Experience_Avg  \
# 0                                 0.367832
# 1                                 1.652028
# 2                                      NaN
# 3                                      NaN
# 4                                -0.381898
#
#    Last__RecYds/TmPatt_Above_Experience_Avg  \
# 0                                  0.594719
# 1                                  1.652028
# 2                                  0.000000
# 3                                  0.000000
# 4                                 -0.381898
#
#    AVG__RecYds/TmPatt_Above_Experience_Avg  \
# 0                                 0.238443
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    First_RecYds/TmPatt_Above_Experience_Avg.1  \
# 0                                   -0.028191
# 1                                   -1.549014
# 2                                   -1.419456
# 3                                   -1.216119
# 4                                   -1.284073
#
#    Best_RecYds/TmPatt_Above_Experience_Avg.1  \
# 0                                   0.746863
# 1                                   0.982732
# 2                                  -1.236693
# 3                                  -1.216119
# 4                                  -1.284073
#
#    Last__RecYds/TmPatt_Above_Experience_Avg.1  \
# 0                                    0.746863
# 1                                    0.982732
# 2                                   -1.236693
# 3                                   -1.216119
# 4                                   -1.284073
#
#    AVG__RecYds/TmPatt_Above_Experience_Avg.1  First_Dominator  Best_Dominator  \
# 0                                   0.191975         0.356559        0.356559
# 1                                  -0.283141         0.194512        0.354658
# 2                                  -1.328075         0.096802        0.096802
# 3                                        NaN         0.047736        0.047736
# 4                                        NaN         0.109889        0.109889
#
#    Last_Dominator  AVG_Dominator_(Min_2_Seasons)  First_Dominator.1  \
# 0        0.340734                       0.318456           0.329132
# 1        0.354658                       0.274585           0.354658
# 2        0.037029                       0.066915                NaN
# 3        0.047736                       0.047736                NaN
# 4        0.109889                       0.109889           0.073259
#
#    Best_Dominator.1  Last_Dominator.1  AVG_Dominator_(Min_2_Seasons).1  \
# 0          0.340734          0.340734                         0.309313
# 1          0.354658          0.354658                              NaN
# 2          0.000000          0.000000                              NaN
# 3          0.000000          0.000000                              NaN
# 4          0.073259          0.073259                              NaN
#
#    First_Doa  Last_Doa  Best_Doa  Doa_(AVG)  First_MS_rec_Yards  \
# 0   0.134972  0.030209  0.134972    0.08259            0.258263
# 1   0.047224  0.047224  0.047224        NaN            0.401625
# 2        NaN  0.000000  0.000000        NaN                 NaN
# 3        NaN  0.000000  0.000000        NaN                 NaN
# 4  -0.234175 -0.234175 -0.234175        NaN            0.093887
#
#    last_ms_rec_yards  Best_MS_rec_Yards  AVG_MS_REC_Yds  First_MS_TDs  \
# 0           0.311098           0.311098         0.28468      0.400000
# 1           0.401625           0.401625             NaN      0.307692
# 2           0.000000           0.000000             NaN           NaN
# 3           0.000000           0.000000             NaN           NaN
# 4           0.093887           0.093887             NaN      0.052632
#
#    Last_MS_TDs  Best_MS_TDs  AVG_MS_TDs  TeamMate_Score  Career_RecYd/GP  \
# 0     0.370370     0.400000    0.347699        0.019802        69.687500
# 1     0.307692     0.307692         NaN             NaN        85.529412
# 2     0.000000     0.000000         NaN             NaN        17.333333
# 3     0.000000     0.000000         NaN             NaN        18.250000
# 4     0.052632     0.052632         NaN             NaN        29.375000
#
#    Career_RecTd/GP  Best_MS_RECs_(>=6_Gms)  Last_MS_RECs_(>=6_Gms)  \
# 0         0.656250                0.250000                0.242798
# 1         0.647059                0.426160                0.426160
# 2         0.111111                0.000000                0.000000
# 3         0.000000                0.000000                0.000000
# 4         0.125000                0.072115                0.072115
#
#    Avg_MS_RECs_(>=6_Gms)  \
# 0               0.211885
# 1               0.426160
# 2               0.000000
# 3               0.000000
# 4               0.072115
#
#    Best_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)  \
# 0                                           0.311098
# 1                                           0.401625
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.093887
#
#    Last_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)  \
# 0                                           0.311098
# 1                                           0.401625
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.093887
#
#    Avg_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)  \
# 0                                           0.284680
# 1                                           0.401625
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.093887
#
#    Best_MS_Yards_above/below_Average_by_age_(top_24_players)  \
# 0                                           0.046294
# 1                                           0.100257
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.207481
#
#    Last_MS_Yards_above/below_Average_by_age_(top_24_players)  \
# 0                                          -0.000050
# 1                                           0.100257
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.207481
#
#    Avg_MS_Yards_above/below_Average_by_age_(top_24_players)  \
# 0                                           0.023122
# 1                                           0.100257
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.207481
#
#    Best_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games  \
# 0                                           0.041425
# 1                                           0.187639
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.113392
#
#    Last_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games  \
# 0                                           0.007747
# 1                                           0.187639
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.113392
#
#    Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games  \
# 0                                           0.024586
# 1                                           0.187639
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.113392
#
#    Best_Player_Above/Below_AVG_Team_REC_Yds_MS  \
# 0                                     0.054473
# 1                                     0.205043
# 2                                     0.000000
# 3                                     0.000000
# 4                                    -0.116388
#
#    Last_Player_Above/Below_AVG_Team_REC_Yds_MS  \
# 0                                     0.028813
# 1                                     0.205043
# 2                                     0.000000
# 3                                     0.000000
# 4                                    -0.116388
#
#    Avg_Player_Above/Below_AVG_Team_REC_Yds_MS  \
# 0                                    0.041643
# 1                                    0.205043
# 2                                    0.000000
# 3                                    0.000000
# 4                                   -0.116388
#
#    Best_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games  \
# 0                                           2.571429
# 1                                           3.531746
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.955285
#
#    Last_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games  \
# 0                                           2.571429
# 1                                           3.531746
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.955285
#
#    Avg_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games  \
# 0                                           2.151947
# 1                                           3.531746
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.955285
#
#    Best_Team_Adjusted_YTMpA  Last_Team_Adjusted_YTMpA  \
# 0                  0.768548                  0.768548
# 1                  1.168419                  1.168419
# 2                  0.000000                  0.000000
# 3                  0.000000                  0.000000
# 4                 -0.840966                 -0.840966
#
#    Avg_Team_Adjusted_YTMpA  Best_Experience_Adjusted_YTMpA  \
# 0                -0.064833                       -1.012979
# 1                 1.168419                       -0.770973
# 2                 0.000000                        0.000000
# 3                 0.000000                        0.000000
# 4                -0.840966                       -2.804899
#
#    Last_Experience_Adjusted_YTMpA  Avg_Experience_Adjusted_YTMpA  BMI  weight  \
# 0                       -2.212744                      -1.965316  NaN     NaN
# 1                       -0.770973                      -0.770973  NaN     NaN
# 2                        0.000000                       0.000000  NaN     NaN
# 3                        0.000000                       0.000000  NaN     NaN
# 4                       -2.804899                      -2.804899  NaN     NaN
#
#    height  bench  3Cone  shuttle  vert  broadInches  Burst_Score  HaSS  WaSS  \
# 0     NaN    NaN    NaN      NaN   NaN          NaN          NaN   NaN   NaN
# 1     NaN    NaN    NaN      NaN   NaN          NaN          NaN   NaN   NaN
# 2     NaN    NaN    NaN      NaN   NaN          NaN          NaN   NaN   NaN
# 3     NaN    NaN    NaN      NaN   NaN          NaN          NaN   NaN   NaN
# 4     NaN    NaN    NaN      NaN   NaN          NaN          NaN   NaN   NaN
#
#    Adjusted_40_Time  G_Y1  Y1_PPR_PPG
# 0               NaN   NaN         NaN
# 1               NaN   NaN         NaN
# 2               NaN   NaN         NaN
# 3               NaN   NaN         NaN
# 4               NaN   NaN         NaN

# %%
# if played under 4 games in Y1 and scored over 5 ppg, drop data from training set
df_t = train_x.join(train_y).join(df.iloc[22:,-2:-1])
df_t = df_t.drop(df_t[(df_t['G_Y1'] < 4) & (df_t['Y1_PPR_PPG'] > 5)].index)
train_x, train_y= df_t.iloc[:,:-2], df_t.iloc[:,-2:-1]

# %%
# fill missing values
train_x['BOA_30%'].fillna(value=24, inplace=True)
x_all['BOA_30%'].fillna(value=24, inplace=True)
train_x['BOA_20%'].fillna(value=24, inplace=True)
x_all['BOA_20%'].fillna(value=24, inplace=True)
train_x['Adjusted_40_Time'].fillna(value=train_x['Adjusted_40_Time'].mean(), inplace=True)
x_all['Adjusted_40_Time'].fillna(value=x_all['Adjusted_40_Time'].mean(), inplace=True)
train_x['Burst_Score'].fillna(value=train_x['Burst_Score'].mean(), inplace=True)
x_all['Burst_Score'].fillna(value=x_all['Burst_Score'].mean(), inplace=True)

# %%
x_all.isna().sum()
# Out:
# DP                                                              0
# Age_In_Draft_Yr                                                15
# BOA_20%                                                         0
# BOA_30%                                                         0
# Career_YPR                                                      0
# Career_REC/g                                                    1
# Career_College_Dominator_Rating                                 0
# Career_Weighted_Dominator                                       0
# Career_YPTpA_Dominator                                          0
# Career_Yards_Dominator                                          0
# First_RecYds/TmPatt                                            50
# Best_RecYds/TmPatt                                              0
# Last_RecYds/TmPatt                                              0
# AVG_RecYds/TmPatt                                              57
# First_RecYds/TmPatt_Above_Conference_AVg                       51
# Best_RecYds/TmPatt_Above_Conference_Avg                         0
# Last__RecYds/TmPatt_Above_Conference_Avg                        0
# AVG__RecYds/TmPatt_Above_Conference_Avg                       108
# First_RecYds/TmPatt_Above_AGE_Avg                              50
# Best_RecYds/TmPatt_Above_AGE_Avg                                0
# Last__RecYds/TmPatt_Above_AGE_Avg                               0
# AVG__RecYds/TmPatt_Above_AGE_Avg                              107
# First_RecYds/TmPatt_Above_Experience_Avg                       52
# Best_RecYds/TmPatt_Above_Experience_Avg                        52
# Last__RecYds/TmPatt_Above_Experience_Avg                        0
# AVG__RecYds/TmPatt_Above_Experience_Avg                       113
# First_RecYds/TmPatt_Above_Experience_Avg.1                    147
# Best_RecYds/TmPatt_Above_Experience_Avg.1                     147
# Last__RecYds/TmPatt_Above_Experience_Avg.1                      0
# AVG__RecYds/TmPatt_Above_Experience_Avg.1                     206
# First_Dominator                                                39
# Best_Dominator                                                  0
# Last_Dominator                                                  0
# AVG_Dominator_(Min_2_Seasons)                                  45
# First_Dominator.1                                               7
# Best_Dominator.1                                                0
# Last_Dominator.1                                                0
# AVG_Dominator_(Min_2_Seasons).1                                48
# First_Doa                                                      23
# Last_Doa                                                        0
# Best_Doa                                                        0
# Doa_(AVG)                                                     102
# First_MS_rec_Yards                                              7
# last_ms_rec_yards                                               0
# Best_MS_rec_Yards                                               0
# AVG_MS_REC_Yds                                                 57
# First_MS_TDs                                                    7
# Last_MS_TDs                                                     0
# Best_MS_TDs                                                     0
# AVG_MS_TDs                                                     56
# TeamMate_Score                                                 60
# Career_RecYd/GP                                                 0
# Career_RecTd/GP                                                 0
# Best_MS_RECs_(>=6_Gms)                                          0
# Last_MS_RECs_(>=6_Gms)                                          0
# Avg_MS_RECs_(>=6_Gms)                                           0
# Best_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)         0
# Last_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)         0
# Avg_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)          0
# Best_MS_Yards_above/below_Average_by_age_(top_24_players)       0
# Last_MS_Yards_above/below_Average_by_age_(top_24_players)       0
# Avg_MS_Yards_above/below_Average_by_age_(top_24_players)        0
# Best_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games      0
# Last_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games      0
# Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games       0
# Best_Player_Above/Below_AVG_Team_REC_Yds_MS                     0
# Last_Player_Above/Below_AVG_Team_REC_Yds_MS                     0
# Avg_Player_Above/Below_AVG_Team_REC_Yds_MS                      0
# Best_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games           0
# Last_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games           0
# Avg_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games            0
# Best_Team_Adjusted_YTMpA                                        0
# Last_Team_Adjusted_YTMpA                                        0
# Avg_Team_Adjusted_YTMpA                                         0
# Best_Experience_Adjusted_YTMpA                                  0
# Last_Experience_Adjusted_YTMpA                                  0
# Avg_Experience_Adjusted_YTMpA                                   0
# BMI                                                           301
# weight                                                        301
# height                                                        301
# bench                                                         457
# 3Cone                                                         495
# shuttle                                                       483
# vert                                                          387
# broadInches                                                   394
# Burst_Score                                                     0
# HaSS                                                          355
# WaSS                                                          355
# Adjusted_40_Time                                                0
# dtype: int64

# %%
missing_threshold = .01
cntr = i = 0

while i < len(train_x.columns):
    if((train_x[train_x.columns[i]].isnull().sum()/len(train_x.index)) > missing_threshold):
        print(train_x.columns[i])
        train_x = train_x.drop(train_x.columns[i], axis=1)
        x_all = x_all.drop(x_all.columns[i], axis=1)
    
        cntr += 1
    else:
        i += 1

print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# Age_In_Draft_Yr
# First_RecYds/TmPatt
# AVG_RecYds/TmPatt
# First_RecYds/TmPatt_Above_Conference_AVg
# AVG__RecYds/TmPatt_Above_Conference_Avg
# First_RecYds/TmPatt_Above_AGE_Avg
# AVG__RecYds/TmPatt_Above_AGE_Avg
# First_RecYds/TmPatt_Above_Experience_Avg
# Best_RecYds/TmPatt_Above_Experience_Avg
# AVG__RecYds/TmPatt_Above_Experience_Avg
# First_RecYds/TmPatt_Above_Experience_Avg.1
# Best_RecYds/TmPatt_Above_Experience_Avg.1
# AVG__RecYds/TmPatt_Above_Experience_Avg.1
# First_Dominator
# AVG_Dominator_(Min_2_Seasons)
# AVG_Dominator_(Min_2_Seasons).1
# First_Doa
# Doa_(AVG)
# AVG_MS_REC_Yds
# AVG_MS_TDs
# TeamMate_Score
# BMI
# weight
# height
# bench
# 3Cone
# shuttle
# vert
# broadInches
# HaSS
# WaSS
# > 31 features were deleted.
# > 58 features remain.

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 799 entries, 22 to 824
# Data columns (total 58 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   DP                                                          799 non-null    int64
#  1   BOA_20%                                                     799 non-null    float64
#  2   BOA_30%                                                     799 non-null    float64
#  3   Career_YPR                                                  799 non-null    float64
#  4   Career_REC/g                                                798 non-null    float64
#  5   Career_College_Dominator_Rating                             799 non-null    float64
#  6   Career_Weighted_Dominator                                   799 non-null    float64
#  7   Career_YPTpA_Dominator                                      799 non-null    float64
#  8   Career_Yards_Dominator                                      799 non-null    float64
#  9   Best_RecYds/TmPatt                                          799 non-null    float64
#  10  Last_RecYds/TmPatt                                          799 non-null    float64
#  11  Best_RecYds/TmPatt_Above_Conference_Avg                     799 non-null    float64
#  12  Last__RecYds/TmPatt_Above_Conference_Avg                    799 non-null    float64
#  13  Best_RecYds/TmPatt_Above_AGE_Avg                            799 non-null    float64
#  14  Last__RecYds/TmPatt_Above_AGE_Avg                           799 non-null    float64
#  15  Last__RecYds/TmPatt_Above_Experience_Avg                    799 non-null    float64
#  16  Last__RecYds/TmPatt_Above_Experience_Avg.1                  799 non-null    float64
#  17  Best_Dominator                                              799 non-null    float64
#  18  Last_Dominator                                              799 non-null    float64
#  19  First_Dominator.1                                           794 non-null    float64
#  20  Best_Dominator.1                                            799 non-null    float64
#  21  Last_Dominator.1                                            799 non-null    float64
#  22  Last_Doa                                                    799 non-null    float64
#  23  Best_Doa                                                    799 non-null    float64
#  24  First_MS_rec_Yards                                          794 non-null    float64
#  25  last_ms_rec_yards                                           799 non-null    float64
#  26  Best_MS_rec_Yards                                           799 non-null    float64
#  27  First_MS_TDs                                                794 non-null    float64
#  28  Last_MS_TDs                                                 799 non-null    float64
#  29  Best_MS_TDs                                                 799 non-null    float64
#  30  Career_RecYd/GP                                             799 non-null    float64
#  31  Career_RecTd/GP                                             799 non-null    float64
#  32  Best_MS_RECs_(>=6_Gms)                                      799 non-null    float64
#  33  Last_MS_RECs_(>=6_Gms)                                      799 non-null    float64
#  34  Avg_MS_RECs_(>=6_Gms)                                       799 non-null    float64
#  35  Best_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)     799 non-null    float64
#  36  Last_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)     799 non-null    float64
#  37  Avg_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)      799 non-null    float64
#  38  Best_MS_Yards_above/below_Average_by_age_(top_24_players)   799 non-null    float64
#  39  Last_MS_Yards_above/below_Average_by_age_(top_24_players)   799 non-null    float64
#  40  Avg_MS_Yards_above/below_Average_by_age_(top_24_players)    799 non-null    float64
#  41  Best_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games  799 non-null    float64
#  42  Last_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games  799 non-null    float64
#  43  Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   799 non-null    float64
#  44  Best_Player_Above/Below_AVG_Team_REC_Yds_MS                 799 non-null    float64
#  45  Last_Player_Above/Below_AVG_Team_REC_Yds_MS                 799 non-null    float64
#  46  Avg_Player_Above/Below_AVG_Team_REC_Yds_MS                  799 non-null    float64
#  47  Best_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games       799 non-null    float64
#  48  Last_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games       799 non-null    float64
#  49  Avg_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games        799 non-null    float64
#  50  Best_Team_Adjusted_YTMpA                                    799 non-null    float64
#  51  Last_Team_Adjusted_YTMpA                                    799 non-null    float64
#  52  Avg_Team_Adjusted_YTMpA                                     799 non-null    float64
#  53  Best_Experience_Adjusted_YTMpA                              799 non-null    float64
#  54  Last_Experience_Adjusted_YTMpA                              799 non-null    float64
#  55  Avg_Experience_Adjusted_YTMpA                               799 non-null    float64
#  56  Burst_Score                                                 799 non-null    float64
#  57  Adjusted_40_Time                                            799 non-null    float64
# dtypes: float64(57), int64(1)
# memory usage: 368.3 KB

# %%
# drop features with low correlation
corr_threshold = .05
cntr = i = 0

while i < len(train_x.columns):
    if(abs(train_x[train_x.columns[i]].corr(train_y[train_y.columns[0]])) < corr_threshold):
        print(train_x.columns[i])
        train_x = train_x.drop(train_x.columns[i], axis=1)
        x_all = x_all.drop(x_all.columns[i], axis=1)
    
        cntr += 1
    else:
        i += 1

print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# > 0 features were deleted.
# > 58 features remain.

# %%
# remove highly collinear features, keeping the feature w/strongest correlation to y-var
corr_thres = .70
drop_cntr = i = j_flag = i_flag = 0

while i < len(train_x.columns):
    j = i+1
    while j < len(train_x.columns):
        if (abs(train_x[train_x.columns[i]].corr(train_x[train_x.columns[j]])) > corr_thres):
            if abs(train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64'))) <= abs(train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64'))):
                print("deleted:", train_x.columns[i], " ", train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),
                      "\nkept:\t", train_x.columns[j], " ", train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),"\n");
                train_x = train_x.drop(train_x.columns[i], axis=1)
                x_all = x_all.drop(x_all.columns[i], axis=1)
                drop_cntr += 1
                i_flag = 1
                break
            else:
                print("deleted:", train_x.columns[j], " ", train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),
                      "\nkept:\t", train_x.columns[i], " ", train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),"\n");
                train_x = train_x.drop(train_x.columns[j], axis=1)
                x_all = x_all.drop(x_all.columns[j], axis=1)
                drop_cntr += 1
                j_flag = 1
        if j_flag == 0:
            j += 1
        j_flag = 0
    if i_flag == 0:
        i += 1
    i_flag = 0
                                                                                            
print('\033[1m' + '> ' + str(drop_cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# deleted: BOA_20%   -0.27850135448328767
# kept:	 Avg_MS_Yards_above/below_Average_by_age_(top_24_players)   0.2894201437127
#
# deleted: Career_REC/g   0.2791270205322228
# kept:	 Career_RecYd/GP   0.32496561228351845
#
# deleted: Career_College_Dominator_Rating   0.20446472522019865
# kept:	 Career_Weighted_Dominator   0.22164422618617088
#
# deleted: Career_Weighted_Dominator   0.22164422618617088
# kept:	 Career_Yards_Dominator   0.22613836037420348
#
# deleted: Best_RecYds/TmPatt   0.3224634627629376
# kept:	 Career_YPTpA_Dominator   0.33158453849240227
#
# deleted: Last_RecYds/TmPatt   0.329820652931901
# kept:	 Career_YPTpA_Dominator   0.33158453849240227
#
# deleted: Career_YPTpA_Dominator   0.33158453849240227
# kept:	 Best_RecYds/TmPatt_Above_Conference_Avg   0.3324619688357142
#
# deleted: Best_Dominator.1   0.18596338699794077
# kept:	 Career_Yards_Dominator   0.22613836037420348
#
# deleted: Last_Dominator.1   0.20779373630156855
# kept:	 Career_Yards_Dominator   0.22613836037420348
#
# deleted: Last_Doa   0.20697262873211106
# kept:	 Career_Yards_Dominator   0.22613836037420348
#
# deleted: Best_Doa   0.18336514884799757
# kept:	 Career_Yards_Dominator   0.22613836037420348
#
# deleted: Career_Yards_Dominator   0.22613836037420348
# kept:	 last_ms_rec_yards   0.22965140794240826
#
# deleted: Best_RecYds/TmPatt_Above_Conference_Avg   0.3324619688357142
# kept:	 Last__RecYds/TmPatt_Above_Conference_Avg   0.33332844103444087
#
# deleted: Last__RecYds/TmPatt_Above_Conference_Avg   0.33332844103444087
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3620893630452695
#
# deleted: Last__RecYds/TmPatt_Above_AGE_Avg   0.36185051913270927
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3620893630452695
#
# deleted: Last__RecYds/TmPatt_Above_Experience_Avg   0.3261152393689218
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3620893630452695
#
# deleted: Avg_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)   0.27434794329066226
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3620893630452695
#
# deleted: Best_MS_Yards_above/below_Average_by_age_(top_24_players)   0.2185415118972019
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3620893630452695
#
# deleted: Avg_MS_Yards_above/below_Average_by_age_(top_24_players)   0.2894201437127
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3620893630452695
#
# deleted: Best_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games   0.34136562379184443
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3620893630452695
#
# deleted: Last_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games   0.3359315506273228
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3620893630452695
#
# deleted: Avg_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games   0.339829934552282
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3620893630452695
#
# deleted: Best_Team_Adjusted_YTMpA   0.26925719567027295
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3620893630452695
#
# deleted: Best_Experience_Adjusted_YTMpA   0.21006047998779065
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3620893630452695
#
# deleted: Best_Dominator   0.2521045573972943
# kept:	 Last_Dominator   0.27743905665495305
#
# deleted: Last_Team_Adjusted_YTMpA   0.2655625425830698
# kept:	 Last_Dominator   0.27743905665495305
#
# deleted: First_Dominator.1   0.16539016429205877
# kept:	 First_MS_rec_Yards   0.18901586872826348
#
# deleted: First_MS_TDs   0.13485673859223418
# kept:	 First_MS_rec_Yards   0.18901586872826348
#
# deleted: Best_MS_rec_Yards   0.21977688551853652
# kept:	 last_ms_rec_yards   0.22965140794240826
#
# deleted: Last_MS_TDs   0.1821042346152788
# kept:	 last_ms_rec_yards   0.22965140794240826
#
# deleted: Best_MS_TDs   0.15592643506828985
# kept:	 last_ms_rec_yards   0.22965140794240826
#
# deleted: Best_MS_RECs_(>=6_Gms)   0.17094722200659776
# kept:	 last_ms_rec_yards   0.22965140794240826
#
# deleted: Last_MS_RECs_(>=6_Gms)   0.1690615711409948
# kept:	 last_ms_rec_yards   0.22965140794240826
#
# deleted: Avg_MS_RECs_(>=6_Gms)   0.22874037413571513
# kept:	 last_ms_rec_yards   0.22965140794240826
#
# deleted: Best_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)   0.21834514681157446
# kept:	 last_ms_rec_yards   0.22965140794240826
#
# deleted: Last_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)   0.21959977067023814
# kept:	 last_ms_rec_yards   0.22965140794240826
#
# deleted: Last_MS_Yards_above/below_Average_by_age_(top_24_players)   0.2182438458885437
# kept:	 last_ms_rec_yards   0.22965140794240826
#
# deleted: Career_RecTd/GP   0.3198789388275416
# kept:	 Career_RecYd/GP   0.32496561228351845
#
# deleted: Avg_Team_Adjusted_YTMpA   0.2244908338299568
# kept:	 Career_RecYd/GP   0.32496561228351845
#
# deleted: Last_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.0804122101537271
# kept:	 Best_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.11159322480805821
#
# deleted: Best_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.11159322480805821
# kept:	 Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.19636354914351947
#
# deleted: Best_Player_Above/Below_AVG_Team_REC_Yds_MS   0.08984010112578981
# kept:	 Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.19636354914351947
#
# deleted: Avg_Player_Above/Below_AVG_Team_REC_Yds_MS   0.16845560140894125
# kept:	 Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.19636354914351947
#
# deleted: Avg_Experience_Adjusted_YTMpA   0.19923110089878257
# kept:	 Last_Experience_Adjusted_YTMpA   0.21338850347127686
#
# > 44 features were deleted.
# > 14 features remain.

# %%
# manual drops

# list_to_drop = []
# cntr = 0

# for i in list_to_drop:
#     x_all = x_all.drop(i, axis=1)
#     train_x = train_x.drop(i, axis=1)
#     cntr += 1


# print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
# print('\033[1m' + '> ' + str(len(x_all.columns)) + ' features remain.' + '\033[0m')#

# %%
train_x = train_x.fillna(x_all.mean())
x_all = x_all.fillna(x_all.mean())

# %%
print(train_x.isna().sum())
# Out:
# DP                                                           0
# BOA_30%                                                      0
# Career_YPR                                                   0
# Best_RecYds/TmPatt_Above_AGE_Avg                             0
# Last__RecYds/TmPatt_Above_Experience_Avg.1                   0
# Last_Dominator                                               0
# First_MS_rec_Yards                                           0
# last_ms_rec_yards                                            0
# Career_RecYd/GP                                              0
# Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games    0
# Last_Player_Above/Below_AVG_Team_REC_Yds_MS                  0
# Last_Experience_Adjusted_YTMpA                               0
# Burst_Score                                                  0
# Adjusted_40_Time                                             0
# dtype: int64

# %%
# print correlations
i = 0
while i < len(train_x.columns):
    corr = abs(train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')))
    print(train_x.columns[i],": {0:.2f}%".format(corr*100),sep='')
    i += 1
# Out:
# DP: 65.04%
# BOA_30%: 30.49%
# Career_YPR: 13.79%
# Best_RecYds/TmPatt_Above_AGE_Avg: 36.21%
# Last__RecYds/TmPatt_Above_Experience_Avg.1: 35.27%
# Last_Dominator: 27.74%
# First_MS_rec_Yards: 18.88%
# last_ms_rec_yards: 22.97%
# Career_RecYd/GP: 32.50%
# Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games: 19.64%
# Last_Player_Above/Below_AVG_Team_REC_Yds_MS: 5.80%
# Last_Experience_Adjusted_YTMpA: 21.34%
# Burst_Score: 10.74%
# Adjusted_40_Time: 20.06%

# %%
# Correlation Heatmap
plt.figure(figsize=(20, 10))
sns.heatmap(abs(train_x.join(train_y).astype('float64').corr()), annot=True)
# Out:
# <AxesSubplot:>

# %%
len(train_x.columns)
# Out:
# 14

# %%
len(train_x)
# Out:
# 799

# %%
#todo:
   #set up param_grid
   #figure out best scoring function for scorers
   #note that it is fitting to train_x and train_y, maybe do it with the stratified split instead?
   #make table pretty and post
   #get scoring metrics for resume
    
param_grid = dict(
    learning_rate=[0.01,0.05],
    n_estimators=[150,200,250,300],
    subsample=[.7],
    max_features=[10,12,14],
    max_depth=[2],
    min_samples_leaf=[5,7,10],
    min_samples_split=[10,20,30],
)
scorer_05p = make_scorer(
    mean_pinball_loss,
    alpha=.05,
    greater_is_better=False,  # maximize the negative loss
)
scorer_95p = make_scorer(
    mean_pinball_loss,
    alpha=.95,
    greater_is_better=False,  # maximize the negative loss
)

# %%
# gridsearch for 0.05 quantile
gsearch_low = GridSearchCV(
    estimator=GradientBoostingRegressor(alpha=0.05,loss='quantile'),
    param_grid=param_grid,
    scoring=scorer_05p,
    n_jobs=-1,
    cv=5)
gsearch_low.fit(train_x, np.ravel(train_y))
gsearch_low.best_params_
# Out:
# {'learning_rate': 0.01,
#  'max_depth': 2,
#  'max_features': 10,
#  'min_samples_leaf': 5,
#  'min_samples_split': 20,
#  'n_estimators': 300,
#  'subsample': 0.7}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance

feature_importance = gsearch_low.best_estimator_.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 8))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(x_all.columns)[sorted_idx])
plt.title('Feature Importance (MDI) of 5% Quantile Regressor')
fig.tight_layout()
plt.show()

# %%
# gridsearch for 0.50 quantile, which minimizes the mean absolute error (MAE)
# gsearch_median = GridSearchCV(
#     estimator=GradientBoostingRegressor(alpha=0.50,loss='quantile'),
#     param_grid=param_grid,
#     scoring='neg_mean_absolute_error',
#     n_jobs=-1,
#     cv=5)
# gsearch_median.fit(train_x, np.ravel(train_y))
# gsearch_median.best_params_

# %%
# gridsearch for 0.95 quantile
gsearch_high = GridSearchCV(
    estimator=GradientBoostingRegressor(alpha=0.95,loss='quantile'),
    param_grid=param_grid,
    scoring=scorer_95p,
    n_jobs=-1,
    cv=5)
gsearch_high.fit(train_x, np.ravel(train_y))
gsearch_high.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 2,
#  'max_features': 12,
#  'min_samples_leaf': 5,
#  'min_samples_split': 10,
#  'n_estimators': 200,
#  'subsample': 0.7}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance

feature_importance = gsearch_high.best_estimator_.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 8))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(x_all.columns)[sorted_idx])
plt.title('Feature Importance (MDI) of 95% Quantile Regressor')
fig.tight_layout()
plt.show()

# %%
low_preds = np.zeros(len(x_all))
#median_preds = np.zeros(len(x_all))
high_preds = np.zeros(len(x_all))
# average predictions over a range of seeds [0,99]
for x in range(100):
    low_preds = (low_preds + gsearch_low.predict(x_all))/2
#    median_preds = (median_preds + gsearch_median.predict(x_all))/2
    high_preds = (high_preds + gsearch_high.predict(x_all))/2
    
#output = pd.DataFrame({'5%':low_preds,'50%':median_preds,'95%':high_preds}).astype('float')
output = pd.DataFrame({'5%':low_preds, '95%':high_preds}).astype('float')
print("done")
# Out:
# done

# %%
#printing results prints dataframe but takes too long to render on github
def red_background_2022(cell_value):
    highlight = 'background-color: tomato;'
    default = ''
    if cell_value == 2022:
        return highlight
    else:
        return default 

pd.set_option('display.max_rows', 10000) 
pd.set_option('display.max_columns', 1000)    
results = labels_all.join(y_all).join(output)
#results = labels_all.join(output)
#results = results.sort_values(by=['0.50'], ascending=False).reset_index(drop=True)
results = results.sort_values(by=['Draft_Year','95%'], ascending=False).reset_index(drop=True)
#results = results.drop('Draft Year', axis=1)
results.loc[:, "Y1_PPR_PPG"] = results["Y1_PPR_PPG"].map('{:.2f}'.format)
results["5%"] = results["5%"].map('{:.2f}'.format)
results["95%"] = results["95%"].map('{:.2f}'.format)
cm = sns.color_palette("inferno", as_cmap=True)
results1 = results.style.set_table_styles([dict(selector='th', props=[('text-align', 'center')])]).background_gradient(cmap=cm, subset=['5%','95%'],vmin=-0.99, vmax=17.07)
results1.set_properties(**{'text-align': 'center'},subset=['5%','95%','Player','School'])
results.style.background_gradient(cmap=cm, subset=['5%','95%']).applymap(red_background_2022)
# Out:
# <style type="text/css">
# #T_a4749_row0_col6, #T_a4749_row1_col6, #T_a4749_row2_col6, #T_a4749_row3_col6, #T_a4749_row4_col6, #T_a4749_row5_col6, #T_a4749_row6_col6, #T_a4749_row7_col6, #T_a4749_row8_col6, #T_a4749_row9_col6, #T_a4749_row10_col6, #T_a4749_row11_col6, #T_a4749_row12_col6, #T_a4749_row13_col6, #T_a4749_row14_col6, #T_a4749_row15_col6, #T_a4749_row16_col6, #T_a4749_row17_col6, #T_a4749_row18_col6, #T_a4749_row19_col6, #T_a4749_row20_col6, #T_a4749_row21_col6, #T_a4749_row22_col6, #T_a4749_row23_col6, #T_a4749_row24_col6, #T_a4749_row25_col6, #T_a4749_row26_col6, #T_a4749_row27_col6, #T_a4749_row28_col6, #T_a4749_row29_col6, #T_a4749_row30_col6, #T_a4749_row31_col6, #T_a4749_row32_col6, #T_a4749_row33_col6, #T_a4749_row34_col6, #T_a4749_row35_col6, #T_a4749_row36_col6, #T_a4749_row37_col6, #T_a4749_row38_col6, #T_a4749_row39_col6, #T_a4749_row40_col6, #T_a4749_row41_col6, #T_a4749_row42_col6, #T_a4749_row43_col6, #T_a4749_row44_col6, #T_a4749_row45_col6, #T_a4749_row46_col6, #T_a4749_row47_col6, #T_a4749_row48_col6, #T_a4749_row49_col6, #T_a4749_row50_col6, #T_a4749_row51_col6, #T_a4749_row52_col6, #T_a4749_row53_col6, #T_a4749_row54_col6, #T_a4749_row55_col6, #T_a4749_row56_col6, #T_a4749_row57_col6, #T_a4749_row58_col6, #T_a4749_row59_col6, #T_a4749_row60_col6, #T_a4749_row61_col6, #T_a4749_row62_col6, #T_a4749_row63_col6, #T_a4749_row64_col6, #T_a4749_row65_col6, #T_a4749_row66_col6, #T_a4749_row67_col6, #T_a4749_row68_col6, #T_a4749_row69_col6, #T_a4749_row70_col6, #T_a4749_row71_col6, #T_a4749_row72_col6, #T_a4749_row73_col6, #T_a4749_row74_col6, #T_a4749_row75_col6, #T_a4749_row76_col6, #T_a4749_row77_col6, #T_a4749_row78_col6, #T_a4749_row79_col6, #T_a4749_row80_col6, #T_a4749_row81_col6, #T_a4749_row82_col6, #T_a4749_row83_col6, #T_a4749_row84_col6, #T_a4749_row85_col6, #T_a4749_row86_col6, #T_a4749_row87_col6, #T_a4749_row88_col6, #T_a4749_row89_col6, #T_a4749_row90_col6, #T_a4749_row91_col6, #T_a4749_row92_col6, #T_a4749_row93_col6, #T_a4749_row93_col7, #T_a4749_row94_col6, #T_a4749_row94_col7, #T_a4749_row95_col6, #T_a4749_row96_col6, #T_a4749_row97_col6, #T_a4749_row98_col6, #T_a4749_row99_col6, #T_a4749_row100_col6, #T_a4749_row101_col6, #T_a4749_row102_col6, #T_a4749_row103_col6, #T_a4749_row104_col6, #T_a4749_row105_col6, #T_a4749_row106_col6, #T_a4749_row107_col6, #T_a4749_row108_col6, #T_a4749_row109_col6, #T_a4749_row110_col6, #T_a4749_row111_col6, #T_a4749_row112_col6, #T_a4749_row114_col6, #T_a4749_row115_col6, #T_a4749_row116_col6, #T_a4749_row117_col6, #T_a4749_row118_col6, #T_a4749_row119_col6, #T_a4749_row120_col6, #T_a4749_row121_col6, #T_a4749_row122_col6, #T_a4749_row123_col6, #T_a4749_row124_col6, #T_a4749_row125_col6, #T_a4749_row126_col6, #T_a4749_row127_col6, #T_a4749_row128_col6, #T_a4749_row129_col6, #T_a4749_row130_col6, #T_a4749_row131_col6, #T_a4749_row132_col6, #T_a4749_row133_col6, #T_a4749_row134_col6, #T_a4749_row135_col6, #T_a4749_row136_col6, #T_a4749_row137_col6, #T_a4749_row138_col6, #T_a4749_row139_col6, #T_a4749_row140_col6, #T_a4749_row141_col6, #T_a4749_row142_col6, #T_a4749_row143_col6, #T_a4749_row144_col6, #T_a4749_row145_col6, #T_a4749_row146_col6, #T_a4749_row147_col6, #T_a4749_row148_col6, #T_a4749_row149_col6, #T_a4749_row150_col6, #T_a4749_row151_col6, #T_a4749_row152_col6, #T_a4749_row153_col6, #T_a4749_row154_col6, #T_a4749_row155_col6, #T_a4749_row156_col6, #T_a4749_row157_col6, #T_a4749_row158_col6, #T_a4749_row159_col6, #T_a4749_row160_col6, #T_a4749_row161_col6, #T_a4749_row162_col6, #T_a4749_row163_col6, #T_a4749_row164_col6, #T_a4749_row165_col6, #T_a4749_row166_col6, #T_a4749_row167_col6, #T_a4749_row169_col6, #T_a4749_row170_col6, #T_a4749_row171_col6, #T_a4749_row172_col6, #T_a4749_row173_col6, #T_a4749_row174_col6, #T_a4749_row175_col6, #T_a4749_row176_col6, #T_a4749_row177_col6, #T_a4749_row178_col6, #T_a4749_row179_col6, #T_a4749_row180_col6, #T_a4749_row181_col6, #T_a4749_row182_col6, #T_a4749_row183_col6, #T_a4749_row184_col6, #T_a4749_row185_col6, #T_a4749_row186_col6 ...

# %%
# check the 90% interval coverage accuracy
def coverage_fraction(y, y_low, y_high):
    return np.mean(np.logical_and(y >= y_low, y <= y_high))

# %%
coverage_fraction(train_y.values.ravel(), gsearch_low.predict(train_x), gsearch_high.predict(train_x))
# Out:
# 0.9361702127659575

# %%
results.to_excel("~/Desktop/wr_y1_quant.xlsx")
