# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import arange
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_pinball_loss

# %%
# load data
pd.set_option('display.max_rows', 10000) 
pd.set_option('display.max_columns', 1000)
df = pd.read_excel('~/nfl_dashboard/ml_models/data/wr_data.xlsx')
df.drop(['Clean_Name','NFL_POS','DR','Y1_PPR_PPG','G_Y1','G_Y2','G_Y3','Y1_PPR_Pts','Pts_Y2','Pts_Y3','Y1-Y3_Total_PPR'], axis=1, inplace=True)
df.sort_values(by='Draft_Year', ascending=False, inplace=True, ignore_index=True)

# split data
labels_all = df.iloc[:, 0:5]
x_all = df.iloc[:, 5:-2] # all features
y_all = df.iloc[:, -1:] # all y data
train_x = df.iloc[149:, 5:-2] # features with at least 3 nfl years
train_y = df.iloc[149:, -1:] # y data with at least 3 nfl years

# %%
df.head()
# Out:
#             Name          School      Conference  Draft_Year Landing_Team  \
# 0    Jayden Reed  Michigan State  Big Ten (East)        2023          NaN
# 1     Josh Downs  North Carolina   ACC (Coastal)        2023          NaN
# 2  Marcus Rosemy         Georgia      SEC (East)        2023          NaN
# 3      Ajou Ajou         Clemson  ACC (Atlantic)        2023          NaN
# 4   Demond Demas       Texas A&M      SEC (West)        2023          NaN
#
#     DP  Age_In_Draft_Yr  BOA_20%  BOA_30%  Career_YPR  Career_REC/g  \
# 0  167             22.0     18.0     18.0   15.067568      4.625000
# 1   35             22.0     20.0     20.0   13.462963      6.352941
# 2  300             21.0      NaN      NaN   14.181818      1.222222
# 3  300             21.0      NaN      NaN   12.166667      1.500000
# 4  300             22.0      NaN      NaN   15.666667      1.875000
#
#    Career_College_Dominator_Rating  Career_Weighted_Dominator  \
# 0                         0.518508                   0.487391
# 1                         0.531988                   0.574257
# 2                         0.000000                   0.000000
# 3                         0.000000                   0.000000
# 4                         0.109889                   0.128454
#
#    Career_YPTpA_Dominator  Career_Yards_Dominator  First_RecYds/TmPatt  \
# 0                2.571429                0.311098             2.202594
# 1                3.531746                0.401625             3.531746
# 2                0.000000                0.026449                  NaN
# 3                0.000000                0.029376                  NaN
# 4                0.955285                0.093887             0.955285
#
#    Best_RecYds/TmPatt  Last_RecYds/TmPatt  AVG_RecYds/TmPatt  \
# 0            2.571429            2.571429           2.151947
# 1            3.531746            3.531746           3.531746
# 2            0.000000            0.000000                NaN
# 3            0.000000            0.000000                NaN
# 4            0.955285            0.955285           0.955285
#
#    First_RecYds/TmPatt_Above_Conference_AVg  \
# 0                                  0.274091
# 1                                  1.704642
# 2                                       NaN
# 3                                       NaN
# 4                                 -1.124022
#
#    Best_RecYds/TmPatt_Above_Conference_Avg  \
# 0                                 0.602738
# 1                                 1.704642
# 2                                 0.000000
# 3                                 0.000000
# 4                                -1.124022
#
#    Last__RecYds/TmPatt_Above_Conference_Avg  \
# 0                                  0.602738
# 1                                  1.704642
# 2                                  0.000000
# 3                                  0.000000
# 4                                 -1.124022
#
#    AVG__RecYds/TmPatt_Above_Conference_Avg  First_RecYds/TmPatt_Above_AGE_Avg  \
# 0                                 0.189569                           0.594896
# 1                                      NaN                           1.102227
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                          -1.474235
#
#    Best_RecYds/TmPatt_Above_AGE_Avg  Last__RecYds/TmPatt_Above_AGE_Avg  \
# 0                          0.594896                           0.004845
# 1                          1.102227                           1.102227
# 2                          0.000000                           0.000000
# 3                          0.000000                           0.000000
# 4                         -1.474235                          -1.474235
#
#    AVG__RecYds/TmPatt_Above_AGE_Avg  First_RecYds/TmPatt_Above_Experience_Avg  \
# 0                          -0.04932                                  0.594719
# 1                               NaN                                  1.652028
# 2                               NaN                                       NaN
# 3                               NaN                                       NaN
# 4                               NaN                                 -0.381898
#
#    Best_RecYds/TmPatt_Above_Experience_Avg  \
# 0                                 0.367832
# 1                                 1.652028
# 2                                      NaN
# 3                                      NaN
# 4                                -0.381898
#
#    Last__RecYds/TmPatt_Above_Experience_Avg  \
# 0                                  0.594719
# 1                                  1.652028
# 2                                  0.000000
# 3                                  0.000000
# 4                                 -0.381898
#
#    AVG__RecYds/TmPatt_Above_Experience_Avg  \
# 0                                 0.238443
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    First_RecYds/TmPatt_Above_Experience_Avg.1  \
# 0                                   -0.028191
# 1                                   -1.549014
# 2                                   -1.419456
# 3                                   -1.216119
# 4                                   -1.284073
#
#    Best_RecYds/TmPatt_Above_Experience_Avg.1  \
# 0                                   0.746863
# 1                                   0.982732
# 2                                  -1.236693
# 3                                  -1.216119
# 4                                  -1.284073
#
#    Last__RecYds/TmPatt_Above_Experience_Avg.1  \
# 0                                    0.746863
# 1                                    0.982732
# 2                                   -1.236693
# 3                                   -1.216119
# 4                                   -1.284073
#
#    AVG__RecYds/TmPatt_Above_Experience_Avg.1  First_Dominator  Best_Dominator  \
# 0                                   0.191975         0.356559        0.356559
# 1                                  -0.283141         0.194512        0.354658
# 2                                  -1.328075         0.096802        0.096802
# 3                                        NaN         0.047736        0.047736
# 4                                        NaN         0.109889        0.109889
#
#    Last_Dominator  AVG_Dominator_(Min_2_Seasons)  First_Dominator.1  \
# 0        0.340734                       0.318456           0.329132
# 1        0.354658                       0.274585           0.354658
# 2        0.037029                       0.066915                NaN
# 3        0.047736                       0.047736                NaN
# 4        0.109889                       0.109889           0.073259
#
#    Best_Dominator.1  Last_Dominator.1  AVG_Dominator_(Min_2_Seasons).1  \
# 0          0.340734          0.340734                         0.309313
# 1          0.354658          0.354658                              NaN
# 2          0.000000          0.000000                              NaN
# 3          0.000000          0.000000                              NaN
# 4          0.073259          0.073259                              NaN
#
#    First_Doa  Last_Doa  Best_Doa  Doa_(AVG)  First_MS_rec_Yards  \
# 0   0.134972  0.030209  0.134972    0.08259            0.258263
# 1   0.047224  0.047224  0.047224        NaN            0.401625
# 2        NaN  0.000000  0.000000        NaN                 NaN
# 3        NaN  0.000000  0.000000        NaN                 NaN
# 4  -0.234175 -0.234175 -0.234175        NaN            0.093887
#
#    last_ms_rec_yards  Best_MS_rec_Yards  AVG_MS_REC_Yds  First_MS_TDs  \
# 0           0.311098           0.311098         0.28468      0.400000
# 1           0.401625           0.401625             NaN      0.307692
# 2           0.000000           0.000000             NaN           NaN
# 3           0.000000           0.000000             NaN           NaN
# 4           0.093887           0.093887             NaN      0.052632
#
#    Last_MS_TDs  Best_MS_TDs  AVG_MS_TDs  TeamMate_Score  Career_RecYd/GP  \
# 0     0.370370     0.400000    0.347699        0.019802        69.687500
# 1     0.307692     0.307692         NaN             NaN        85.529412
# 2     0.000000     0.000000         NaN             NaN        17.333333
# 3     0.000000     0.000000         NaN             NaN        18.250000
# 4     0.052632     0.052632         NaN             NaN        29.375000
#
#    Career_RecTd/GP  Best_MS_RECs_(>=6_Gms)  Last_MS_RECs_(>=6_Gms)  \
# 0         0.656250                0.250000                0.242798
# 1         0.647059                0.426160                0.426160
# 2         0.111111                0.000000                0.000000
# 3         0.000000                0.000000                0.000000
# 4         0.125000                0.072115                0.072115
#
#    Avg_MS_RECs_(>=6_Gms)  \
# 0               0.211885
# 1               0.426160
# 2               0.000000
# 3               0.000000
# 4               0.072115
#
#    Best_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)  \
# 0                                           0.311098
# 1                                           0.401625
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.093887
#
#    Last_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)  \
# 0                                           0.311098
# 1                                           0.401625
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.093887
#
#    Avg_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)  \
# 0                                           0.284680
# 1                                           0.401625
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.093887
#
#    Best_MS_Yards_above/below_Average_by_age_(top_24_players)  \
# 0                                           0.046294
# 1                                           0.100257
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.207481
#
#    Last_MS_Yards_above/below_Average_by_age_(top_24_players)  \
# 0                                          -0.000050
# 1                                           0.100257
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.207481
#
#    Avg_MS_Yards_above/below_Average_by_age_(top_24_players)  \
# 0                                           0.023122
# 1                                           0.100257
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.207481
#
#    Best_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games  \
# 0                                           0.041425
# 1                                           0.187639
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.113392
#
#    Last_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games  \
# 0                                           0.007747
# 1                                           0.187639
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.113392
#
#    Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games  \
# 0                                           0.024586
# 1                                           0.187639
# 2                                           0.000000
# 3                                           0.000000
# 4                                          -0.113392
#
#    Best_Player_Above/Below_AVG_Team_REC_Yds_MS  \
# 0                                     0.054473
# 1                                     0.205043
# 2                                     0.000000
# 3                                     0.000000
# 4                                    -0.116388
#
#    Last_Player_Above/Below_AVG_Team_REC_Yds_MS  \
# 0                                     0.028813
# 1                                     0.205043
# 2                                     0.000000
# 3                                     0.000000
# 4                                    -0.116388
#
#    Avg_Player_Above/Below_AVG_Team_REC_Yds_MS  \
# 0                                    0.041643
# 1                                    0.205043
# 2                                    0.000000
# 3                                    0.000000
# 4                                   -0.116388
#
#    Best_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games  \
# 0                                           2.571429
# 1                                           3.531746
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.955285
#
#    Last_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games  \
# 0                                           2.571429
# 1                                           3.531746
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.955285
#
#    Avg_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games  \
# 0                                           2.151947
# 1                                           3.531746
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.955285
#
#    Best_Team_Adjusted_YTMpA  Last_Team_Adjusted_YTMpA  \
# 0                  0.768548                  0.768548
# 1                  1.168419                  1.168419
# 2                  0.000000                  0.000000
# 3                  0.000000                  0.000000
# 4                 -0.840966                 -0.840966
#
#    Avg_Team_Adjusted_YTMpA  Best_Experience_Adjusted_YTMpA  \
# 0                -0.064833                       -1.012979
# 1                 1.168419                       -0.770973
# 2                 0.000000                        0.000000
# 3                 0.000000                        0.000000
# 4                -0.840966                       -2.804899
#
#    Last_Experience_Adjusted_YTMpA  Avg_Experience_Adjusted_YTMpA  BMI  weight  \
# 0                       -2.212744                      -1.965316  NaN     NaN
# 1                       -0.770973                      -0.770973  NaN     NaN
# 2                        0.000000                       0.000000  NaN     NaN
# 3                        0.000000                       0.000000  NaN     NaN
# 4                       -2.804899                      -2.804899  NaN     NaN
#
#    height  bench  3Cone  shuttle  vert  broadInches  Burst_Score  HaSS  WaSS  \
# 0     NaN    NaN    NaN      NaN   NaN          NaN          NaN   NaN   NaN
# 1     NaN    NaN    NaN      NaN   NaN          NaN          NaN   NaN   NaN
# 2     NaN    NaN    NaN      NaN   NaN          NaN          NaN   NaN   NaN
# 3     NaN    NaN    NaN      NaN   NaN          NaN          NaN   NaN   NaN
# 4     NaN    NaN    NaN      NaN   NaN          NaN          NaN   NaN   NaN
#
#    Adjusted_40_Time  G_Y1-Y3  Y1-Y3_PPR_PPG
# 0               NaN      NaN            NaN
# 1               NaN      NaN            NaN
# 2               NaN      NaN            NaN
# 3               NaN      NaN            NaN
# 4               NaN      NaN            NaN

# %%
# fill missing values
train_x['BOA_30%'].fillna(value=24, inplace=True)
x_all['BOA_30%'].fillna(value=24, inplace=True)
train_x['BOA_20%'].fillna(value=24, inplace=True)
x_all['BOA_20%'].fillna(value=24, inplace=True)
train_x['Adjusted_40_Time'].fillna(value=train_x['Adjusted_40_Time'].mean(), inplace=True)
x_all['Adjusted_40_Time'].fillna(value=x_all['Adjusted_40_Time'].mean(), inplace=True)
train_x['Burst_Score'].fillna(value=train_x['Burst_Score'].mean(), inplace=True)
x_all['Burst_Score'].fillna(value=x_all['Burst_Score'].mean(), inplace=True)

# %%
x_all.isna().sum()
# Out:
# DP                                                              0
# Age_In_Draft_Yr                                                15
# BOA_20%                                                         0
# BOA_30%                                                         0
# Career_YPR                                                      0
# Career_REC/g                                                    1
# Career_College_Dominator_Rating                                 0
# Career_Weighted_Dominator                                       0
# Career_YPTpA_Dominator                                          0
# Career_Yards_Dominator                                          0
# First_RecYds/TmPatt                                            50
# Best_RecYds/TmPatt                                              0
# Last_RecYds/TmPatt                                              0
# AVG_RecYds/TmPatt                                              57
# First_RecYds/TmPatt_Above_Conference_AVg                       51
# Best_RecYds/TmPatt_Above_Conference_Avg                         0
# Last__RecYds/TmPatt_Above_Conference_Avg                        0
# AVG__RecYds/TmPatt_Above_Conference_Avg                       108
# First_RecYds/TmPatt_Above_AGE_Avg                              50
# Best_RecYds/TmPatt_Above_AGE_Avg                                0
# Last__RecYds/TmPatt_Above_AGE_Avg                               0
# AVG__RecYds/TmPatt_Above_AGE_Avg                              107
# First_RecYds/TmPatt_Above_Experience_Avg                       52
# Best_RecYds/TmPatt_Above_Experience_Avg                        52
# Last__RecYds/TmPatt_Above_Experience_Avg                        0
# AVG__RecYds/TmPatt_Above_Experience_Avg                       113
# First_RecYds/TmPatt_Above_Experience_Avg.1                    147
# Best_RecYds/TmPatt_Above_Experience_Avg.1                     147
# Last__RecYds/TmPatt_Above_Experience_Avg.1                      0
# AVG__RecYds/TmPatt_Above_Experience_Avg.1                     206
# First_Dominator                                                39
# Best_Dominator                                                  0
# Last_Dominator                                                  0
# AVG_Dominator_(Min_2_Seasons)                                  45
# First_Dominator.1                                               7
# Best_Dominator.1                                                0
# Last_Dominator.1                                                0
# AVG_Dominator_(Min_2_Seasons).1                                48
# First_Doa                                                      23
# Last_Doa                                                        0
# Best_Doa                                                        0
# Doa_(AVG)                                                     102
# First_MS_rec_Yards                                              7
# last_ms_rec_yards                                               0
# Best_MS_rec_Yards                                               0
# AVG_MS_REC_Yds                                                 57
# First_MS_TDs                                                    7
# Last_MS_TDs                                                     0
# Best_MS_TDs                                                     0
# AVG_MS_TDs                                                     56
# TeamMate_Score                                                 60
# Career_RecYd/GP                                                 0
# Career_RecTd/GP                                                 0
# Best_MS_RECs_(>=6_Gms)                                          0
# Last_MS_RECs_(>=6_Gms)                                          0
# Avg_MS_RECs_(>=6_Gms)                                           0
# Best_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)         0
# Last_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)         0
# Avg_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)          0
# Best_MS_Yards_above/below_Average_by_age_(top_24_players)       0
# Last_MS_Yards_above/below_Average_by_age_(top_24_players)       0
# Avg_MS_Yards_above/below_Average_by_age_(top_24_players)        0
# Best_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games      0
# Last_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games      0
# Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games       0
# Best_Player_Above/Below_AVG_Team_REC_Yds_MS                     0
# Last_Player_Above/Below_AVG_Team_REC_Yds_MS                     0
# Avg_Player_Above/Below_AVG_Team_REC_Yds_MS                      0
# Best_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games           0
# Last_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games           0
# Avg_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games            0
# Best_Team_Adjusted_YTMpA                                        0
# Last_Team_Adjusted_YTMpA                                        0
# Avg_Team_Adjusted_YTMpA                                         0
# Best_Experience_Adjusted_YTMpA                                  0
# Last_Experience_Adjusted_YTMpA                                  0
# Avg_Experience_Adjusted_YTMpA                                   0
# BMI                                                           301
# weight                                                        301
# height                                                        301
# bench                                                         457
# 3Cone                                                         495
# shuttle                                                       483
# vert                                                          387
# broadInches                                                   394
# Burst_Score                                                     0
# HaSS                                                          355
# WaSS                                                          355
# Adjusted_40_Time                                                0
# dtype: int64

# %%
missing_threshold = .01
cntr = i = 0

while i < len(train_x.columns):
    if((train_x[train_x.columns[i]].isnull().sum()/len(train_x.index)) > missing_threshold):
        print(train_x.columns[i])
        train_x = train_x.drop(train_x.columns[i], axis=1)
        x_all = x_all.drop(x_all.columns[i], axis=1)
    
        cntr += 1
    else:
        i += 1

print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# First_RecYds/TmPatt
# AVG_RecYds/TmPatt
# First_RecYds/TmPatt_Above_Conference_AVg
# AVG__RecYds/TmPatt_Above_Conference_Avg
# First_RecYds/TmPatt_Above_AGE_Avg
# AVG__RecYds/TmPatt_Above_AGE_Avg
# First_RecYds/TmPatt_Above_Experience_Avg
# Best_RecYds/TmPatt_Above_Experience_Avg
# AVG__RecYds/TmPatt_Above_Experience_Avg
# First_RecYds/TmPatt_Above_Experience_Avg.1
# Best_RecYds/TmPatt_Above_Experience_Avg.1
# AVG__RecYds/TmPatt_Above_Experience_Avg.1
# First_Dominator
# AVG_Dominator_(Min_2_Seasons)
# AVG_Dominator_(Min_2_Seasons).1
# First_Doa
# Doa_(AVG)
# AVG_MS_REC_Yds
# AVG_MS_TDs
# TeamMate_Score
# BMI
# weight
# height
# bench
# 3Cone
# shuttle
# vert
# broadInches
# HaSS
# WaSS
# > 30 features were deleted.
# > 59 features remain.

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 149 to 824
# Data columns (total 59 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   DP                                                          676 non-null    int64
#  1   Age_In_Draft_Yr                                             676 non-null    float64
#  2   BOA_20%                                                     676 non-null    float64
#  3   BOA_30%                                                     676 non-null    float64
#  4   Career_YPR                                                  676 non-null    float64
#  5   Career_REC/g                                                675 non-null    float64
#  6   Career_College_Dominator_Rating                             676 non-null    float64
#  7   Career_Weighted_Dominator                                   676 non-null    float64
#  8   Career_YPTpA_Dominator                                      676 non-null    float64
#  9   Career_Yards_Dominator                                      676 non-null    float64
#  10  Best_RecYds/TmPatt                                          676 non-null    float64
#  11  Last_RecYds/TmPatt                                          676 non-null    float64
#  12  Best_RecYds/TmPatt_Above_Conference_Avg                     676 non-null    float64
#  13  Last__RecYds/TmPatt_Above_Conference_Avg                    676 non-null    float64
#  14  Best_RecYds/TmPatt_Above_AGE_Avg                            676 non-null    float64
#  15  Last__RecYds/TmPatt_Above_AGE_Avg                           676 non-null    float64
#  16  Last__RecYds/TmPatt_Above_Experience_Avg                    676 non-null    float64
#  17  Last__RecYds/TmPatt_Above_Experience_Avg.1                  676 non-null    float64
#  18  Best_Dominator                                              676 non-null    float64
#  19  Last_Dominator                                              676 non-null    float64
#  20  First_Dominator.1                                           672 non-null    float64
#  21  Best_Dominator.1                                            676 non-null    float64
#  22  Last_Dominator.1                                            676 non-null    float64
#  23  Last_Doa                                                    676 non-null    float64
#  24  Best_Doa                                                    676 non-null    float64
#  25  First_MS_rec_Yards                                          672 non-null    float64
#  26  last_ms_rec_yards                                           676 non-null    float64
#  27  Best_MS_rec_Yards                                           676 non-null    float64
#  28  First_MS_TDs                                                672 non-null    float64
#  29  Last_MS_TDs                                                 676 non-null    float64
#  30  Best_MS_TDs                                                 676 non-null    float64
#  31  Career_RecYd/GP                                             676 non-null    float64
#  32  Career_RecTd/GP                                             676 non-null    float64
#  33  Best_MS_RECs_(>=6_Gms)                                      676 non-null    float64
#  34  Last_MS_RECs_(>=6_Gms)                                      676 non-null    float64
#  35  Avg_MS_RECs_(>=6_Gms)                                       676 non-null    float64
#  36  Best_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)     676 non-null    float64
#  37  Last_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)     676 non-null    float64
#  38  Avg_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)      676 non-null    float64
#  39  Best_MS_Yards_above/below_Average_by_age_(top_24_players)   676 non-null    float64
#  40  Last_MS_Yards_above/below_Average_by_age_(top_24_players)   676 non-null    float64
#  41  Avg_MS_Yards_above/below_Average_by_age_(top_24_players)    676 non-null    float64
#  42  Best_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games  676 non-null    float64
#  43  Last_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games  676 non-null    float64
#  44  Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   676 non-null    float64
#  45  Best_Player_Above/Below_AVG_Team_REC_Yds_MS                 676 non-null    float64
#  46  Last_Player_Above/Below_AVG_Team_REC_Yds_MS                 676 non-null    float64
#  47  Avg_Player_Above/Below_AVG_Team_REC_Yds_MS                  676 non-null    float64
#  48  Best_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games       676 non-null    float64
#  49  Last_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games       676 non-null    float64
#  50  Avg_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games        676 non-null    float64
#  51  Best_Team_Adjusted_YTMpA                                    676 non-null    float64
#  52  Last_Team_Adjusted_YTMpA                                    676 non-null    float64
#  53  Avg_Team_Adjusted_YTMpA                                     676 non-null    float64
#  54  Best_Experience_Adjusted_YTMpA                              676 non-null    float64
#  55  Last_Experience_Adjusted_YTMpA                              676 non-null    float64
#  56  Avg_Experience_Adjusted_YTMpA                               676 non-null    float64
#  57  Burst_Score                                                 676 non-null    float64
#  58  Adjusted_40_Time                                            676 non-null    float64
# dtypes: float64(58), int64(1)
# memory usage: 311.7 KB

# %%
# drop features with low correlation
corr_threshold = .05
cntr = i = 0

while i < len(train_x.columns):
    if(abs(train_x[train_x.columns[i]].corr(train_y[train_y.columns[0]])) < corr_threshold):
        print(train_x.columns[i])
        train_x = train_x.drop(train_x.columns[i], axis=1)
        x_all = x_all.drop(x_all.columns[i], axis=1)
    
        cntr += 1
    else:
        i += 1

print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# > 0 features were deleted.
# > 59 features remain.

# %%
# remove highly collinear features, keeping the feature w/strongest correlation to y-var
corr_thres = .70
drop_cntr = i = j_flag = i_flag = 0

while i < len(train_x.columns):
    j = i+1
    while j < len(train_x.columns):
        if (abs(train_x[train_x.columns[i]].corr(train_x[train_x.columns[j]])) > corr_thres):
            if abs(train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64'))) <= abs(train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64'))):
                print("deleted:", train_x.columns[i], " ", train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),
                      "\nkept:\t", train_x.columns[j], " ", train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),"\n");
                train_x = train_x.drop(train_x.columns[i], axis=1)
                x_all = x_all.drop(x_all.columns[i], axis=1)
                drop_cntr += 1
                i_flag = 1
                break
            else:
                print("deleted:", train_x.columns[j], " ", train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),
                      "\nkept:\t", train_x.columns[i], " ", train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),"\n");
                train_x = train_x.drop(train_x.columns[j], axis=1)
                x_all = x_all.drop(x_all.columns[j], axis=1)
                drop_cntr += 1
                j_flag = 1
        if j_flag == 0:
            j += 1
        j_flag = 0
    if i_flag == 0:
        i += 1
    i_flag = 0
                                                                                            
print('\033[1m' + '> ' + str(drop_cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# deleted: BOA_20%   -0.3221813288056266
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3962239116698654
#
# deleted: BOA_30%   -0.3352145536977119
# kept:	 Avg_MS_Yards_above/below_Average_by_age_(top_24_players)   0.3433925213588536
#
# deleted: Career_REC/g   0.31646594648443094
# kept:	 Career_RecYd/GP   0.35747787262893477
#
# deleted: Career_College_Dominator_Rating   0.2248237290891492
# kept:	 Career_Weighted_Dominator   0.2498207943947374
#
# deleted: Career_Weighted_Dominator   0.2498207943947374
# kept:	 Career_Yards_Dominator   0.26261132388393427
#
# deleted: Best_RecYds/TmPatt   0.33292332565447075
# kept:	 Career_YPTpA_Dominator   0.3424004468471875
#
# deleted: Last_RecYds/TmPatt   0.3405861860583628
# kept:	 Career_YPTpA_Dominator   0.3424004468471875
#
# deleted: Career_YPTpA_Dominator   0.3424004468471875
# kept:	 Best_RecYds/TmPatt_Above_Conference_Avg   0.3702121435334391
#
# deleted: Best_Dominator.1   0.2086338265232308
# kept:	 Career_Yards_Dominator   0.26261132388393427
#
# deleted: Last_Dominator.1   0.22640143771605534
# kept:	 Career_Yards_Dominator   0.26261132388393427
#
# deleted: Last_Doa   0.2306710411954016
# kept:	 Career_Yards_Dominator   0.26261132388393427
#
# deleted: Best_Doa   0.21121975098843698
# kept:	 Career_Yards_Dominator   0.26261132388393427
#
# deleted: last_ms_rec_yards   0.2619752362308146
# kept:	 Career_Yards_Dominator   0.26261132388393427
#
# deleted: Best_MS_rec_Yards   0.2596444452778579
# kept:	 Career_Yards_Dominator   0.26261132388393427
#
# deleted: Last_MS_TDs   0.19269645294231988
# kept:	 Career_Yards_Dominator   0.26261132388393427
#
# deleted: Best_MS_TDs   0.1703261012898414
# kept:	 Career_Yards_Dominator   0.26261132388393427
#
# deleted: Best_MS_RECs_(>=6_Gms)   0.2102355535423107
# kept:	 Career_Yards_Dominator   0.26261132388393427
#
# deleted: Last_MS_RECs_(>=6_Gms)   0.21989163165575804
# kept:	 Career_Yards_Dominator   0.26261132388393427
#
# deleted: Career_Yards_Dominator   0.26261132388393427
# kept:	 Avg_MS_RECs_(>=6_Gms)   0.29412941224792183
#
# deleted: Best_RecYds/TmPatt_Above_Conference_Avg   0.3702121435334391
# kept:	 Last__RecYds/TmPatt_Above_Conference_Avg   0.3721252232209484
#
# deleted: Last__RecYds/TmPatt_Above_Conference_Avg   0.3721252232209484
# kept:	 Best_RecYds/TmPatt_Above_AGE_Avg   0.3962239116698654
#
# deleted: Best_RecYds/TmPatt_Above_AGE_Avg   0.3962239116698654
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Last__RecYds/TmPatt_Above_Experience_Avg   0.3578360820443371
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Last_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)   0.25763288952906555
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Last_MS_Yards_above/below_Average_by_age_(top_24_players)   0.25818776567043344
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Avg_MS_Yards_above/below_Average_by_age_(top_24_players)   0.3433925213588536
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Best_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games   0.3798729878312346
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Last_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games   0.37109172996123935
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Avg_YTMpA_(Rec_Yards_Per_Team_Pass_Attempt)_>6_games   0.3806696733538975
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Best_Team_Adjusted_YTMpA   0.3053310147714077
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Last_Team_Adjusted_YTMpA   0.3130851439477325
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Best_Experience_Adjusted_YTMpA   0.3114789429688139
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Last_Experience_Adjusted_YTMpA   0.33794957991817576
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Avg_Experience_Adjusted_YTMpA   0.32823816665365463
# kept:	 Last__RecYds/TmPatt_Above_AGE_Avg   0.40657722635999644
#
# deleted: Best_Dominator   0.2589192336630239
# kept:	 Last_Dominator   0.2836087381815049
#
# deleted: First_Dominator.1   0.21087994832645424
# kept:	 First_MS_rec_Yards   0.22661713245620574
#
# deleted: First_MS_TDs   0.18431578027500176
# kept:	 First_MS_rec_Yards   0.22661713245620574
#
# deleted: Career_RecTd/GP   0.3461303317100982
# kept:	 Career_RecYd/GP   0.35747787262893477
#
# deleted: Avg_MS_RECs_(>=6_Gms)   0.29412941224792183
# kept:	 Career_RecYd/GP   0.35747787262893477
#
# deleted: Avg_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)   0.320831965954139
# kept:	 Career_RecYd/GP   0.35747787262893477
#
# deleted: Avg_Team_Adjusted_YTMpA   0.26938241042818595
# kept:	 Career_RecYd/GP   0.35747787262893477
#
# deleted: Best_MS_REC_Yards_(for_AVG_if_played_more_then_6_games)   0.26031965022028775
# kept:	 Best_MS_Yards_above/below_Average_by_age_(top_24_players)   0.2608459561344784
#
# deleted: Last_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.1020446204594097
# kept:	 Best_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.13650577694589205
#
# deleted: Best_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.13650577694589205
# kept:	 Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.22412784742785938
#
# deleted: Best_Player_Above/Below_AVG_Team_REC_Yds_MS   0.11188529187047165
# kept:	 Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.22412784742785938
#
# deleted: Avg_Player_Above/Below_AVG_Team_REC_Yds_MS   0.18820489910241148
# kept:	 Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games   0.22412784742785938
#
# > 46 features were deleted.
# > 13 features remain.

# %%
# manual drops

# list_to_drop = []
# cntr = 0

# for i in list_to_drop:
#     x_all = x_all.drop(i, axis=1)
#     train_x = train_x.drop(i, axis=1)
#     cntr += 1


# print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
# print('\033[1m' + '> ' + str(len(x_all.columns)) + ' features remain.' + '\033[0m')#

# %%
train_x = train_x.fillna(x_all.mean())
x_all = x_all.fillna(x_all.mean())

# %%
print(train_x.isna().sum())
# Out:
# DP                                                           0
# Age_In_Draft_Yr                                              0
# Career_YPR                                                   0
# Last__RecYds/TmPatt_Above_AGE_Avg                            0
# Last__RecYds/TmPatt_Above_Experience_Avg.1                   0
# Last_Dominator                                               0
# First_MS_rec_Yards                                           0
# Career_RecYd/GP                                              0
# Best_MS_Yards_above/below_Average_by_age_(top_24_players)    0
# Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games    0
# Last_Player_Above/Below_AVG_Team_REC_Yds_MS                  0
# Burst_Score                                                  0
# Adjusted_40_Time                                             0
# dtype: int64

# %%
# print correlations
i = 0
while i < len(train_x.columns):
    corr = abs(train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')))
    print(train_x.columns[i],": {0:.2f}%".format(corr*100),sep='')
    i += 1
# Out:
# DP: 63.46%
# Age_In_Draft_Yr: 28.73%
# Career_YPR: 13.74%
# Last__RecYds/TmPatt_Above_AGE_Avg: 40.66%
# Last__RecYds/TmPatt_Above_Experience_Avg.1: 34.13%
# Last_Dominator: 28.36%
# First_MS_rec_Yards: 22.63%
# Career_RecYd/GP: 35.75%
# Best_MS_Yards_above/below_Average_by_age_(top_24_players): 26.08%
# Avg_Player_Above/Below_AVG_Conference_REC_Yds_MS_>6_games: 22.41%
# Last_Player_Above/Below_AVG_Team_REC_Yds_MS: 7.86%
# Burst_Score: 8.02%
# Adjusted_40_Time: 12.82%

# %%
# Correlation Heatmap
plt.figure(figsize=(20, 10))
sns.heatmap(abs(train_x.join(train_y).astype('float64').corr()), annot=True)
# Out:
# <AxesSubplot:>

# %%
len(train_x.columns)
# Out:
# 13

# %%
#todo:
   #set up param_grid
   #figure out best scoring function for scorers
   #note that it is fitting to train_x and train_y, maybe do it with the stratified split instead?
   #make table pretty and post
   #get scoring metrics for resume
    
param_grid = dict(
    learning_rate=[0.01,0.05],
    n_estimators=[150,200,250,300],
    subsample=[.7],
    max_features=[10,11,13],
    max_depth=[2],
    min_samples_leaf=[5,7,10],
    min_samples_split=[10,20,30],
)
scorer_05p = make_scorer(
    mean_pinball_loss,
    alpha=.05,
    greater_is_better=False,  # maximize the negative loss
)
scorer_95p = make_scorer(
    mean_pinball_loss,
    alpha=.95,
    greater_is_better=False,  # maximize the negative loss
)

# %%
# gridsearch for 0.05 quantile
gsearch_low = GridSearchCV(
    estimator=GradientBoostingRegressor(alpha=0.05,loss='quantile'),
    param_grid=param_grid,
    scoring=scorer_05p,
    n_jobs=-1,
    cv=5)
gsearch_low.fit(train_x, np.ravel(train_y))
gsearch_low.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 2,
#  'max_features': 11,
#  'min_samples_leaf': 5,
#  'min_samples_split': 30,
#  'n_estimators': 300,
#  'subsample': 0.7}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance

feature_importance = gsearch_low.best_estimator_.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 8))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(x_all.columns)[sorted_idx])
plt.title('Feature Importance (MDI) of 5% Quantile Regressor')
fig.tight_layout()
plt.show()

# %%
# gridsearch for 0.50 quantile, which minimizes the mean absolute error (MAE)
# gsearch_median = GridSearchCV(
#     estimator=GradientBoostingRegressor(alpha=0.50,loss='quantile'),
#     param_grid=param_grid,
#     scoring='neg_mean_absolute_error',
#     n_jobs=-1,
#     cv=5)
# gsearch_median.fit(train_x, np.ravel(train_y))
# gsearch_median.best_params_

# %%
# gridsearch for 0.95 quantile
gsearch_high = GridSearchCV(
    estimator=GradientBoostingRegressor(alpha=0.95,loss='quantile'),
    param_grid=param_grid,
    scoring=scorer_95p,
    n_jobs=-1,
    cv=5)
gsearch_high.fit(train_x, np.ravel(train_y))
gsearch_high.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 2,
#  'max_features': 11,
#  'min_samples_leaf': 5,
#  'min_samples_split': 20,
#  'n_estimators': 250,
#  'subsample': 0.7}

# %%
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance

feature_importance = gsearch_high.best_estimator_.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 8))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(x_all.columns)[sorted_idx])
plt.title('Feature Importance (MDI) of 95% Quantile Regressor')
fig.tight_layout()
plt.show()

# %%
low_preds = np.zeros(len(x_all))
#median_preds = np.zeros(len(x_all))
high_preds = np.zeros(len(x_all))
# average predictions over a range of seeds [0,99]
for x in range(100):
    low_preds = (low_preds + gsearch_low.predict(x_all))/2
#    median_preds = (median_preds + gsearch_median.predict(x_all))/2
    high_preds = (high_preds + gsearch_high.predict(x_all))/2
    
#output = pd.DataFrame({'5%':low_preds,'50%':median_preds,'95%':high_preds}).astype('float')
output = pd.DataFrame({'5%':low_preds, '95%':high_preds}).astype('float')
print("done")
# Out:
# done

# %%
#printing results prints dataframe but takes too long to render on github
def red_background_2022(cell_value):
    highlight = 'background-color: tomato;'
    default = ''
    if cell_value == 2022:
        return highlight
    else:
        return default 
    
results = labels_all.join(y_all).join(output)
#results = labels_all.join(output)
#results = results.sort_values(by=['0.50'], ascending=False).reset_index(drop=True)
results = results.sort_values(by=['Draft_Year','95%'], ascending=False).reset_index(drop=True)
#results = results.drop('Draft Year', axis=1)
results.loc[:, "Y1-Y3_PPR_PPG"] = results["Y1-Y3_PPR_PPG"].map('{:.2f}'.format)
results["5%"] = results["5%"].map('{:.2f}'.format)
results["95%"] = results["95%"].map('{:.2f}'.format)
cm = sns.color_palette("inferno", as_cmap=True)
results1 = results.style.set_table_styles([dict(selector='th', props=[('text-align', 'center')])]).background_gradient(cmap=cm, subset=['5%','95%'],vmin=-0.99, vmax=17.07)
results1.set_properties(**{'text-align': 'center'},subset=['5%','95%','Player','School'])
results.style.background_gradient(cmap=cm, subset=['5%','95%']).applymap(red_background_2022)
# Out:
# <style type="text/css">
# #T_9aa30_row0_col6, #T_9aa30_row24_col6, #T_9aa30_row157_col6 {
#   background-color: #f9c932;
#   color: #000000;
# }
# #T_9aa30_row0_col7, #T_9aa30_row1_col7, #T_9aa30_row492_col6, #T_9aa30_row494_col7, #T_9aa30_row607_col7 {
#   background-color: #f67e14;
#   color: #f1f1f1;
# }
# #T_9aa30_row1_col6, #T_9aa30_row667_col6 {
#   background-color: #f5db4c;
#   color: #000000;
# }
# #T_9aa30_row2_col6, #T_9aa30_row23_col7, #T_9aa30_row552_col6 {
#   background-color: #fb9b06;
#   color: #000000;
# }
# #T_9aa30_row2_col7, #T_9aa30_row155_col7, #T_9aa30_row609_col6, #T_9aa30_row676_col6 {
#   background-color: #ef6e21;
#   color: #f1f1f1;
# }
# #T_9aa30_row3_col6, #T_9aa30_row156_col6, #T_9aa30_row550_col6, #T_9aa30_row664_col6, #T_9aa30_row725_col7 {
#   background-color: #f6d543;
#   color: #000000;
# }
# #T_9aa30_row3_col7, #T_9aa30_row32_col7, #T_9aa30_row156_col7, #T_9aa30_row226_col7, #T_9aa30_row228_col6, #T_9aa30_row276_col7, #T_9aa30_row668_col7 {
#   background-color: #ef6c23;
#   color: #f1f1f1;
# }
# #T_9aa30_row4_col6, #T_9aa30_row431_col6, #T_9aa30_row551_col6, #T_9aa30_row671_col6, #T_9aa30_row776_col7 {
#   background-color: #f9c72f;
#   color: #000000;
# }
# #T_9aa30_row4_col7, #T_9aa30_row232_col6 {
#   background-color: #c13a50;
#   color: #f1f1f1;
# }
# #T_9aa30_row5_col6, #T_9aa30_row38_col6, #T_9aa30_row284_col6, #T_9aa30_row779_col6 {
#   background-color: #f9cb35;
#   color: #000000;
# }
# #T_9aa30_row5_col7, #T_9aa30_row344_col7, #T_9aa30_row432_col7, #T_9aa30_row556_col7 {
#   background-color: #c03a51;
#   color: #f1f1f1;
# }
# #T_9aa30_row6_col6, #T_9aa30_row37_col6, #T_9aa30_row44_col6, #T_9aa30_row112_col6, #T_9aa30_row161_col6, #T_9aa30_row170_col6, #T_9aa30_row182_col6, #T_9aa30_row267_col6, #T_9aa30_row347_col6, #T_9aa30_row348_col6, #T_9aa30_row523_col6, #T_9aa30_row555_col6, #T_9aa30_row568_col6, #T_9aa30_row766_col7, #T_9aa30_row790_col6, #T_9aa30_row818_col7 {
#   background-color: #240c4f;
#   color: #f1f1f1;
# }
# #T_9aa30_row6_col7, #T_9aa30_row48_col7, #T_9aa30_row111_col6, #T_9aa30_row121_col7, #T_9aa30_row357_col7, #T_9aa30_row502_col6, #T_9aa30_row513_col7, #T_9aa30_row514_col7, #T_9aa30_row624_col7, #T_9aa30_row798_col7 {
#   background-color: #8d2369;
#   color: #f1f1f1;
# }
# #T_9aa30_row7_col6, #T_9aa30_row498_col6 {
#   background-color: #fac42a;
#   color: #000000;
# }
# #T_9aa30_row7_col7, #T_9aa30_row172_col7, #T_9aa30_row242_col7 {
#   background-color: #8c2369;
#   color: #f1f1f1;
# }
# #T_9aa30_row8_col6, #T_9aa30_row14_col7, #T_9aa30_row117_col6, #T_9aa30_row163_col6, #T_9aa30_row249_col6, #T_9aa30_row355_col6, #T_9aa30_row358_col6, #T_9aa30_row364_col6, #T_9aa30_row435_col6, #T_9aa30_row470_col7, #T_9aa30_row506_col6, #T_9aa30_row510_col6, #T_9aa30_row565_col6, #T_9aa30_row567_col6, #T_9aa30_row586_col7, #T_9aa30_row797_col6 {
#   background-color: #230c4c;
#   color: #f1f1f1;
# }
# #T_9aa30_row8_col7, #T_9aa30_row516_col7 {
#   background-color: #771c6d;
#   color: #f1f1f1;
# }
# #T_9aa30_row9_col6, #T_9aa30_row11_col6, #T_9aa30_row12_col6, #T_9aa30_row13_col6, #T_9aa30_row14_col6, #T_9aa30_row15_col6, #T_9aa30_row16_col6, #T_9aa30_row17_col6, #T_9aa30_row18_col6, #T_9aa30_row19_col6, #T_9aa30_row20_col6, #T_9aa30_row21_col6, #T_9aa30_row45_col6, #T_9aa30_row46_col6, #T_9aa30_row47_col6, #T_9aa30_row51_col6, #T_9aa30_row52_col6, #T_9aa30_row53_col6, #T_9aa30_row54_col6, #T_9aa30_row55_col6, #T_9aa30_row56_col6, #T_9aa30_row57_col6, #T_9aa30_row59_col6, #T_9aa30_row60_col6, #T_9aa30_row61_col6, #T_9aa30_row62_col6, #T_9aa30_row63_col6, #T_9aa30_row64_col6, #T_9aa30_row65_col6, #T_9aa30_row66_col6, #T_9aa30_row67_col6, #T_9aa30_row68_col6, #T_9aa30_row69_col6, #T_9aa30_row70_col6, #T_9aa30_row71_col6, #T_9aa30_row72_col6, #T_9aa30_row73_col6, #T_9aa30_row74_col6, #T_9aa30_row75_col6, #T_9aa30_row76_col6, #T_9aa30_row77_col6, #T_9aa30_row78_col6, #T_9aa30_row79_col6, #T_9aa30_row80_col6, #T_9aa30_row81_col6, #T_9aa30_row82_col6, #T_9aa30_row83_col6, #T_9aa30_row84_col6, #T_9aa30_row85_col6, #T_9aa30_row86_col6, #T_9aa30_row87_col6, #T_9aa30_row88_col6, #T_9aa30_row89_col6, #T_9aa30_row90_col6, #T_9aa30_row91_col6, #T_9aa30_row92_col6, #T_9aa30_row93_col6, #T_9aa30_row94_col6, #T_9aa30_row109_col6, #T_9aa30_row115_col6, #T_9aa30_row116_col6, #T_9aa30_row120_col6, #T_9aa30_row124_col6, #T_9aa30_row127_col6, #T_9aa30_row128_col6, #T_9aa30_row129_col6, #T_9aa30_row130_col6, #T_9aa30_row131_col6, #T_9aa30_row132_col6, #T_9aa30_row133_col6, #T_9aa30_row134_col6, #T_9aa30_row135_col6, #T_9aa30_row136_col6, #T_9aa30_row137_col6, #T_9aa30_row138_col6, #T_9aa30_row139_col6, #T_9aa30_row140_col6, #T_9aa30_row141_col6, #T_9aa30_row142_col6, #T_9aa30_row143_col6, #T_9aa30_row144_col6, #T_9aa30_row145_col6, #T_9aa30_row146_col6, #T_9aa30_row147_col6, #T_9aa30_row148_col6, #T_9aa30_row171_col6, #T_9aa30_row177_col6, #T_9aa30_row180_col6, #T_9aa30_row181_col6, #T_9aa30_row183_col6, #T_9aa30_row184_col6, #T_9aa30_row185_col6, #T_9aa30_row186_col6, #T_9aa30_row187_col6, #T_9aa30_row188_col6, #T_9aa30_row190_col6, #T_9aa30_row191_col6, #T_9aa30_row192_col6, #T_9aa30_row195_col6, #T_9aa30_row196_col6, #T_9aa30_row197_col6, #T_9aa30_row199_col6, #T_9aa30_row200_col6, #T_9aa30_row201_col6, #T_9aa30_row202_col6, #T_9aa30_row203_col6, #T_9aa30_row204_col6, #T_9aa30_row205_col6, #T_9aa30_row206_col6, #T_9aa30_row207_col6, #T_9aa30_row208_col6, #T_9aa30_row209_col6, #T_9aa30_row210_col6, #T_9aa30_row211_col6, #T_9aa30_row212_col6, #T_9aa30_row213_col6, #T_9aa30_row214_col6, #T_9aa30_row215_col6, #T_9aa30_row216_col6, #T_9aa30_row217_col6, #T_9aa30_row218_col6, #T_9aa30_row219_col6, #T_9aa30_row238_col6, #T_9aa30_row240_col6, #T_9aa30_row244_col6, #T_9aa30_row246_col6, #T_9aa30_row247_col6, #T_9aa30_row248_col6, #T_9aa30_row250_col6, #T_9aa30_row252_col6, #T_9aa30_row253_col6, #T_9aa30_row254_col6, #T_9aa30_row256_col6, #T_9aa30_row257_col6, #T_9aa30_row259_col6, #T_9aa30_row261_col6, #T_9aa30_row262_col6, #T_9aa30_row263_col6, #T_9aa30_row264_col6, #T_9aa30_row266_col6, #T_9aa30_row268_col6, #T_9aa30_row269_col6, #T_9aa30_row270_col6, #T_9aa30_row271_col6, #T_9aa30_row282_col6, #T_9aa30_row286_col6, #T_9aa30_row291_col6, #T_9aa30_row296_col6, #T_9aa30_row298_col6, #T_9aa30_row299_col6, #T_9aa30_row301_col6, #T_9aa30_row303_col6, #T_9aa30_row304_col6, #T_9aa30_row305_col6, #T_9aa30_row306_col6, #T_9aa30_row307_col6, #T_9aa30_row310_col6, #T_9aa30_row311_col6, #T_9aa30_row312_col6, #T_9aa30_row315_col6, #T_9aa30_row316_col6, #T_9aa30_row317_col6, #T_9aa30_row318_col6, #T_9aa30_row319_col6, #T_9aa30_row320_col6, #T_9aa30_row321_col6, #T_9aa30_row324_col6, #T_9aa30_row325_col6, #T_9aa30_row326_col6, #T_9aa30_row327_col6, #T_9aa30_row328_col6, #T_9aa30_row329_col6, #T_9aa30_row330_col6, #T_9aa30_row332_col6, #T_9aa30_row346_col6, #T_9aa30_row351_col6, #T_9aa30_row353_col6, #T_9aa30_row354_col6, #T_9aa30_row359_col6, #T_9aa30_row360_col6, #T_9aa30_row362_col6, #T_9aa30_row363_col6, #T_9aa30_row365_col6, #T_9aa30_row366_col6, #T_9aa30_ro ...

# %%
# check the 90% interval coverage accuracy
def coverage_fraction(y, y_low, y_high):
    return np.mean(np.logical_and(y >= y_low, y <= y_high))

# %%
coverage_fraction(train_y.values.ravel(), gsearch_low.predict(train_x), gsearch_high.predict(train_x))
# Out:
# 0.9171597633136095

# %%
results.to_excel("~/Desktop/wr_1-3_quantiles.xlsx")
