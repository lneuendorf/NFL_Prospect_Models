# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import arange
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_pinball_loss

# %%
# load data
pd.set_option('display.max_rows', 10000) 
pd.set_option('display.max_columns', 1000)
df = pd.read_excel('~/nfl_dashboard/ml_models/data/rb_data.xlsx')
df.drop(['Clean_Name','DR','G_Y1','G_Y2','G_Y3','Y1_PPR_Pts','Y1_PPR_PPG','Pts_Y2','Pts_Y3','Y1-Y3_Total_PPR'], axis=1, inplace=True)
df.sort_values(by='Draft_Year', ascending=False, inplace=True, ignore_index=True)

# split data
labels_all = df.iloc[:, 0:5]
x_all = df.iloc[:, 5:-2] # all features
y_all = df.iloc[:, -1:] # all y data
train_x = df.iloc[121:, 5:-2] # features with at least 3 nfl years
train_y = df.iloc[121:, -1:] # y data with at least 3 nfl years

# %%
df.head()
# Out:
#                 Name         School      Conference  Draft_Year Landing_Team  \
# 0  Donald Chaney Jr.     Miami (FL)   ACC (Coastal)        2023          NaN
# 1       Jahmyr Gibbs   Georgia Tech   ACC (Coastal)        2023          NaN
# 2     Bijan Robinson          Texas          Big 12        2023          NaN
# 3        Chris Tyree     Notre Dame  ACC (Atlantic)        2023          NaN
# 4  Deamonte Trayanum  Arizona State  Pac-12 (South)        2023          NaN
#
#     DP  Age_IN_DRAFT_YEAR  BOA_15%  BOA_20%  Career_YPTch  \
# 0  300                 22      NaN      NaN      5.637363
# 1   30                 21     18.0     18.0      6.783505
# 2   12                 21     18.0     19.0      7.208075
# 3  300                 21      NaN      NaN      6.465839
# 4  300                 21      NaN      NaN      5.416667
#
#    Career_YTMA_Dominator  Career_ADJ_YTMA_Dominator  First_REC_Yards_%  \
# 0               0.460438                   0.766709           0.307527
# 1               1.568757                   2.181565           0.397117
# 2               2.138346                   2.581955           0.218020
# 3               0.645309                   0.976687           0.115865
# 4               0.977272                   0.799636           0.016949
#
#    Best_REC_Yards_%  Last_REC_Yards_%  AVG_REC_Yards_%  RUSH%_AVG  \
# 0          0.307527          0.083333         0.286550   0.713450
# 1          0.397117          0.383980         0.389058   0.610942
# 2          0.218020          0.207454         0.211547   0.788453
# 3          0.537500          0.537500         0.310279   0.689721
# 4          0.045238          0.045238         0.033566   0.966434
#
#    First_ADJ_YTMA  Best_ADJ_YTMA  Last_ADJ_YTMA  AVG_ADJ_YTMA  \
# 0        0.766709       0.766709       0.766709      0.766709
# 1        2.219908       2.219908       2.143223      2.181565
# 2        1.723324       2.581955       2.581955      2.152639
# 3        0.731308       0.976687       0.976687      0.853998
# 4        0.799636       0.799636       0.799636      0.799636
#
#    First_Experience_Adjusted_ADJ_YTMA  Best_Experience_Adjusted_ADJ_YTMA  \
# 0                            0.192294                           0.192294
# 1                            1.645494                           1.645494
# 2                            1.067514                           1.715454
# 3                            0.142053                           0.263381
# 4                            0.114829                           0.114829
#
#    Last_Experience_Adjusted_ADJ_YTMA  AVG_Experience_Adjusted_ADJ_YTMA  \
# 0                           0.192294                          0.192294
# 1                           1.621729                          1.633611
# 2                           1.715454                          1.391484
# 3                           0.263381                          0.202717
# 4                           0.114829                          0.114829
#
#    First_YTMA  Best_YTMA  Last_YTMA  AVG_YTMA  \
# 0    0.586381   0.586381   0.334495  0.460438
# 1    1.588921   1.588921   1.548593  1.568757
# 2    1.414857   2.138346   2.138346  1.776601
# 3    0.655374   0.655374   0.635244  0.645309
# 4    1.189516   1.189516   0.765027  0.977272
#
#    First_Experience__Adjusted_YTMA  Best_Experience__Adjusted_YTMA  \
# 0                        -0.111660                       -0.111660
# 1                         0.890881                        0.904157
# 2                         0.673628                        1.149867
# 3                        -0.054055                       -0.054055
# 4                         0.523532                        0.523532
#
#    Last_Experience__Adjusted_YTMA  AVG_Experience__Adjusted_YTMA  \
# 0                       -0.309941                      -0.210801
# 1                        0.904157                       0.897519
# 2                        1.149867                       0.911747
# 3                       -0.158949                      -0.106502
# 4                       -0.016385                       0.253573
#
#    First_Total_Dominator  Best_Total_Dominator  Last_Total_Dominator  \
# 0               0.098011              0.098011              0.019726
# 1               0.207194              0.234335              0.234335
# 2               0.172650              0.289486              0.289486
# 3               0.084615              0.084615              0.074623
# 4               0.131739              0.131739              0.085324
#
#    AVG_Total_Dominator  First_Weighted_Dominator  Best_Weighted_Dominator  \
# 0             0.058868                  0.037508                 0.037508
# 1             0.220765                  0.143970                 0.199952
# 2             0.231068                  0.083566                 0.114832
# 3             0.079619                  0.031585                 0.069542
# 4             0.108532                  0.005148                 0.006008
#
#    Last_Weighted_Dominator  AVG_Weighted_Dominator  First_RushYDs/TMrA  \
# 0                 0.000830                0.019169            0.779661
# 1                 0.179317                0.171961            1.622575
# 2                 0.114832                0.091656            2.157766
# 3                 0.069542                0.043897            0.997988
# 4                 0.006008                0.005578            1.206713
#
#    Best_RushYDs/TMA  Last_RushYDs/TMA  AVG_RushYDs/TMrA  \
# 0          0.779661          0.779661          0.779661
# 1          1.687783          1.687783          1.655179
# 2          2.985430          2.985430          2.571598
# 3          0.997988          0.594929          0.796458
# 4          1.206713          1.206713          1.206713
#
#    First_Cofe_RushYDs/TMrA  Best_Cofe_RushYDs/TMrA  Last_Cofe_RushYDs/TMrA  \
# 0                -0.230596               -0.230596               -0.230596
# 1                 0.612318                0.746487                0.746487
# 2                 0.956174                1.373300                1.373300
# 3                -0.154390               -0.154390               -0.673389
# 4                -0.109052               -0.109052               -0.109052
#
#    AVG_Cofe_RushYDs/TMrA  First_MS_Rec_Yds  Best_MS_Rec_Yds  Last_MS_Rec_Yds  \
# 0                    NaN          0.046885         0.046885         0.001038
# 1               0.679402          0.152185         0.196368         0.196368
# 2               1.164737          0.069975         0.109057         0.109057
# 3                    NaN          0.022815         0.070261         0.070261
# 4                    NaN          0.006435         0.007510         0.007510
#
#    AVG_MS_Rec_Yds  First_MS_Rush_Yards  Best_MS_Rush_Yards  \
# 0        0.023962             0.178492            0.178492
# 1        0.174277             0.240084            0.363194
# 2        0.089516             0.358125            0.470957
# 3        0.046538             0.194434            0.194434
# 4        0.006972             0.270522            0.270522
#
#    Last_MS_Rush_Yards  AVG_MS_Rush_Yards  First_Ms_Rush_TDs  Best_Ms_Rush_TDs  \
# 0            0.027866           0.103179           0.166667          0.166667
# 1            0.363194           0.301639           0.222222          0.266667
# 2            0.470957           0.414541           0.200000          0.440000
# 3            0.118085           0.156259           0.121212          0.121212
# 4            0.157317           0.213919           0.250000          0.250000
#
#    Last_Ms_Rush_TDs  AVG_Ms_Rush_TDs  \
# 0          0.050000         0.108333
# 1          0.266667         0.244444
# 2          0.440000         0.320000
# 3          0.043478         0.082345
# 4          0.176471         0.213235
#
#    YTMpA_Over_Conference_RB1_AVG_(best_year)  Best_RuAtt/GP  Last_RuAtt/GP  \
# 0                                  -0.762780       6.181818       5.500000
# 1                                   0.253036      12.714286      11.916667
# 2                                   0.547482      19.500000      19.500000
# 3                                  -0.537294       6.083333       5.090909
# 4                                  -0.149044      12.250000       8.666667
#
#    Avg_RuAtt/GP  Best_RuYd/GP  Last_RuYd/GP  Avg_RuYd/GP  Best_RuTd/G  \
# 0      6.076923     29.272727     22.000000    28.153846     0.500000
# 1     12.210526     65.714286     62.166667    63.473684     0.571429
# 2     14.789474    112.700000    112.700000    96.315789     1.100000
# 3      5.608696     41.333333     20.181818    31.217391     0.333333
# 4      9.769231     72.500000     44.555556    53.153846     1.000000
#
#    Last_RuTd/G  Avg_RuTd/G  Best_MS_RuATTs  Last_MS_RuATTs  Avg_MS_RuATTs  \
# 0     0.500000    0.307692        0.164649        0.027569       0.096109
# 1     0.333333    0.421053        0.323529        0.323529       0.271641
# 2     1.100000    0.789474        0.430464        0.430464       0.334016
# 3     0.090909    0.217391        0.146881        0.126984       0.136933
# 4     0.666667    0.769231        0.304348        0.162500       0.233424
#
#    Best_Rec/GP  Last_Rec/GP  Avg_Rec/GP  Best_RecYd/GP  Last_RecYd/GP  \
# 0     1.000000     0.500000    0.923077      13.000000       2.000000
# 1     3.428571     2.916667    3.105263      43.285714      38.750000
# 2     2.600000     2.600000    2.157895      29.500000      29.500000
# 3     2.181818     2.181818    1.391304      23.454545      23.454545
# 4     0.444444     0.444444    0.384615       2.111111       2.111111
#
#    Avg_RecYd/GP  Best_RecTD/GP  Last_RecTD/GP  Avg_RecTD/GP  Best_MS_RECs  \
# 0     11.307692       0.000000       0.000000      0.000000      0.046025
# 1     40.421053       0.428571       0.166667      0.263158      0.172414
# 2     25.842105       0.400000       0.400000      0.315789      0.119816
# 3     14.043478       0.181818       0.181818      0.086957      0.083045
# 4      1.846154       0.000000       0.000000      0.000000      0.019608
#
#    Last_MS_RECs  Avg_MS_RECs  Best_MS_RecTd  Last_MS_RecTd  Avg_MS_RecTd  \
# 0      0.003390     0.024707       0.000000       0.000000      0.000000
# 1      0.172414     0.164638       0.214286       0.111111      0.162698
# 2      0.119816     0.095966       0.137931       0.137931      0.100216
# 3      0.083045     0.058839       0.066667       0.066667      0.033333
# 4      0.019417     0.019513       0.000000       0.000000      0.000000
#
#    Best_Pos_Opp_%  Last_Pos_Opp_%  Avg_Pos_Opp_%  Best_Conf_Adjusted_YTMA  \
# 0        0.259868        0.037037       0.148453                -0.240087
# 1        0.501408        0.501408       0.432962                 0.762454
# 2        0.535109        0.535109       0.460303                 1.259753
# 3        0.205063        0.203046       0.204054                -0.149517
# 4        0.381679        0.215223       0.298451                 0.267898
#
#    Last_Conf_Adjusted_YTMA  Avg_Conf_Adjusted_YTMA  Best_Team_Adjusted_YTMA  \
# 0                -0.494221               -0.367154                -0.291941
# 1                 0.719878                0.741166                 0.697407
# 2                 1.259753                0.898222                 1.286951
# 3                -0.169517               -0.159517                -0.208158
# 4                -0.161364                0.053267                -0.044241
#
#    Last_Team_Adjusted_YTMA  Avg_Team_Adjusted_YTMA  \
# 0                -0.535038               -0.413490
# 1                 0.606608                0.652008
# 2                 1.286951                0.917353
# 3                -0.208158               -0.234108
# 4                -0.484516               -0.264379
#
#    Best_Conference_Adjusted_ADJ_YTMA  Last_Conference_Adjusted_ADJ_YTMA  \
# 0                           0.074652                           0.074652
# 1                           1.527852                           1.461455
# 2                           1.799366                           1.799366
# 3                           0.315337                           0.315337
# 4                           0.020257                           0.020257
#
#    Avg_Conference_Adjusted_ADJ_YTMA  Best_Experience_Adjusted_YTMrA  \
# 0                          0.074652                       -0.230596
# 1                          1.494653                        0.746487
# 2                          1.370927                        1.373300
# 3                          0.194816                       -0.154390
# 4                          0.020257                       -0.109052
#
#    Last_Experience_Adjusted_YTMrA  Avg_Experience_Adjusted_YTMrA  \
# 0                       -0.230596                      -0.230596
# 1                        0.746487                       0.679402
# 2                        1.373300                       1.164737
# 3                       -0.673389                      -0.413889
# 4                       -0.109052                      -0.109052
#
#    Best_TDOa_Diff_from_AVG_Total_Dominator  \
# 0                                -0.113072
# 1                                 0.038352
# 2                                 0.078404
# 3                                -0.084227
# 4                                -0.037103
#
#    Last_TDOa_Diff_from_AVG_Total_Dominator  \
# 0                                -0.225910
# 1                                 0.023252
# 2                                 0.078404
# 3                                -0.136460
# 4                                -0.125759
#
#    Avg_TDOa_Diff_from_AVG_Total_Dominator  weight  height  bench  3Cone  \
# 0                               -0.169491     NaN     NaN    NaN    NaN
# 1                                0.030802     NaN     NaN    NaN    NaN
# 2                                0.041106     NaN     NaN    NaN    NaN
# 3                               -0.110344     NaN     NaN    NaN    NaN
# 4                               -0.081431     NaN     NaN    NaN    NaN
#
#    shuttle  vert  broadInches  Burst_Score  HaSS  WaSS  Adjusted_40_Time  \
# 0      NaN   NaN          NaN          NaN   NaN   NaN               NaN
# 1      NaN   NaN          NaN          NaN   NaN   NaN               NaN
# 2      NaN   NaN          NaN          NaN   NaN   NaN               NaN
# 3      NaN   NaN          NaN          NaN   NaN   NaN               NaN
# 4      NaN   NaN          NaN          NaN   NaN   NaN               NaN
#
#    Y1-Y3_Tot_G  Y1-Y3_PPR_PPG
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN

# %%
# if played under 23 games in Y1-Y3 and scored over 10 ppg, drop data from training set
df_t = train_x.join(train_y).join(df.iloc[121:,-2:-1])
df_t = df_t.drop(df_t[(df_t['Y1-Y3_Tot_G'] < 23) & (df_t['Y1-Y3_PPR_PPG'] > 10)].index)
train_x, train_y= df_t.iloc[:,:-2], df_t.iloc[:,-2:-1]

# %%
# fill missing values
train_x['BOA_15%'].fillna(value=24, inplace=True)
x_all['BOA_15%'].fillna(value=24, inplace=True)
train_x['BOA_20%'].fillna(value=24, inplace=True)
x_all['BOA_20%'].fillna(value=24, inplace=True)
train_x['Adjusted_40_Time'].fillna(value=train_x['Adjusted_40_Time'].mean(), inplace=True)
x_all['Adjusted_40_Time'].fillna(value=x_all['Adjusted_40_Time'].mean(), inplace=True)
train_x['Burst_Score'].fillna(value=train_x['Burst_Score'].mean(), inplace=True)
x_all['Burst_Score'].fillna(value=x_all['Burst_Score'].mean(), inplace=True)

# %%
x_all.isna().sum()
# Out:
# DP                                             0
# Age_IN_DRAFT_YEAR                              0
# BOA_15%                                        0
# BOA_20%                                        0
# Career_YPTch                                   0
# Career_YTMA_Dominator                          0
# Career_ADJ_YTMA_Dominator                      0
# First_REC_Yards_%                              2
# Best_REC_Yards_%                               0
# Last_REC_Yards_%                               0
# AVG_REC_Yards_%                                2
# RUSH%_AVG                                      2
# First_ADJ_YTMA                                 0
# Best_ADJ_YTMA                                  0
# Last_ADJ_YTMA                                  0
# AVG_ADJ_YTMA                                   0
# First_Experience_Adjusted_ADJ_YTMA             0
# Best_Experience_Adjusted_ADJ_YTMA              0
# Last_Experience_Adjusted_ADJ_YTMA              0
# AVG_Experience_Adjusted_ADJ_YTMA               0
# First_YTMA                                     2
# Best_YTMA                                      0
# Last_YTMA                                      0
# AVG_YTMA                                       4
# First_Experience__Adjusted_YTMA                0
# Best_Experience__Adjusted_YTMA                 0
# Last_Experience__Adjusted_YTMA                 0
# AVG_Experience__Adjusted_YTMA                  0
# First_Total_Dominator                          0
# Best_Total_Dominator                           0
# Last_Total_Dominator                           0
# AVG_Total_Dominator                            4
# First_Weighted_Dominator                       2
# Best_Weighted_Dominator                        0
# Last_Weighted_Dominator                        2
# AVG_Weighted_Dominator                        55
# First_RushYDs/TMrA                            27
# Best_RushYDs/TMA                               0
# Last_RushYDs/TMA                              27
# AVG_RushYDs/TMrA                              36
# First_Cofe_RushYDs/TMrA                       31
# Best_Cofe_RushYDs/TMrA                         0
# Last_Cofe_RushYDs/TMrA                        31
# AVG_Cofe_RushYDs/TMrA                        148
# First_MS_Rec_Yds                               2
# Best_MS_Rec_Yds                                0
# Last_MS_Rec_Yds                                2
# AVG_MS_Rec_Yds                                55
# First_MS_Rush_Yards                            2
# Best_MS_Rush_Yards                             0
# Last_MS_Rush_Yards                             2
# AVG_MS_Rush_Yards                             10
# First_Ms_Rush_TDs                              2
# Best_Ms_Rush_TDs                               0
# Last_Ms_Rush_TDs                               2
# AVG_Ms_Rush_TDs                               22
# YTMpA_Over_Conference_RB1_AVG_(best_year)     19
# Best_RuAtt/GP                                  0
# Last_RuAtt/GP                                  0
# Avg_RuAtt/GP                                   0
# Best_RuYd/GP                                   0
# Last_RuYd/GP                                   0
# Avg_RuYd/GP                                    0
# Best_RuTd/G                                    0
# Last_RuTd/G                                    0
# Avg_RuTd/G                                     0
# Best_MS_RuATTs                                 0
# Last_MS_RuATTs                                 2
# Avg_MS_RuATTs                                  2
# Best_Rec/GP                                    0
# Last_Rec/GP                                    0
# Avg_Rec/GP                                     0
# Best_RecYd/GP                                  0
# Last_RecYd/GP                                  0
# Avg_RecYd/GP                                   0
# Best_RecTD/GP                                  0
# Last_RecTD/GP                                  0
# Avg_RecTD/GP                                   0
# Best_MS_RECs                                   0
# Last_MS_RECs                                   2
# Avg_MS_RECs                                    2
# Best_MS_RecTd                                  0
# Last_MS_RecTd                                  2
# Avg_MS_RecTd                                   2
# Best_Pos_Opp_%                                 0
# Last_Pos_Opp_%                                19
# Avg_Pos_Opp_%                                 19
# Best_Conf_Adjusted_YTMA                        0
# Last_Conf_Adjusted_YTMA                       23
# Avg_Conf_Adjusted_YTMA                        23
# Best_Team_Adjusted_YTMA                        0
# Last_Team_Adjusted_YTMA                       29
# Avg_Team_Adjusted_YTMA                        29
# Best_Conference_Adjusted_ADJ_YTMA              0
# Last_Conference_Adjusted_ADJ_YTMA             26
# Avg_Conference_Adjusted_ADJ_YTMA              25
# Best_Experience_Adjusted_YTMrA                 0
# Last_Experience_Adjusted_YTMrA                32
# Avg_Experience_Adjusted_YTMrA                 31
# Best_TDOa_Diff_from_AVG_Total_Dominator        0
# Last_TDOa_Diff_from_AVG_Total_Dominator       11
# Avg_TDOa_Diff_from_AVG_Total_Dominator        10
# weight                                       207
# height                                       207
# bench                                        286
# 3Cone                                        374
# shuttle                                      363
# vert                                         253
# broadInches                                  263
# Burst_Score                                    0
# HaSS                                         234
# WaSS                                         234
# Adjusted_40_Time                               0
# dtype: int64

# %%
missing_threshold = .01
cntr = i = 0

while i < len(train_x.columns):
    if((train_x[train_x.columns[i]].isnull().sum()/len(train_x.index)) > missing_threshold):
        print(train_x.columns[i])
        train_x = train_x.drop(train_x.columns[i], axis=1)
        x_all = x_all.drop(x_all.columns[i], axis=1)
    
        cntr += 1
    else:
        i += 1

print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# AVG_Weighted_Dominator
# First_RushYDs/TMrA
# Last_RushYDs/TMA
# AVG_RushYDs/TMrA
# First_Cofe_RushYDs/TMrA
# Last_Cofe_RushYDs/TMrA
# AVG_Cofe_RushYDs/TMrA
# AVG_MS_Rec_Yds
# AVG_MS_Rush_Yards
# AVG_Ms_Rush_TDs
# YTMpA_Over_Conference_RB1_AVG_(best_year)
# Last_Pos_Opp_%
# Avg_Pos_Opp_%
# Last_Conf_Adjusted_YTMA
# Avg_Conf_Adjusted_YTMA
# Last_Team_Adjusted_YTMA
# Avg_Team_Adjusted_YTMA
# Last_Conference_Adjusted_ADJ_YTMA
# Avg_Conference_Adjusted_ADJ_YTMA
# Last_Experience_Adjusted_YTMrA
# Avg_Experience_Adjusted_YTMrA
# Last_TDOa_Diff_from_AVG_Total_Dominator
# Avg_TDOa_Diff_from_AVG_Total_Dominator
# weight
# height
# bench
# 3Cone
# shuttle
# vert
# broadInches
# HaSS
# WaSS
# > 32 features were deleted.
# > 81 features remain.

# %%
# drop features with low correlation
corr_threshold = .05
cntr = i = 0

while i < len(train_x.columns):
    if(abs(train_x[train_x.columns[i]].corr(train_y[train_y.columns[0]])) < corr_threshold):
        print(train_x.columns[i])
        train_x = train_x.drop(train_x.columns[i], axis=1)
        x_all = x_all.drop(x_all.columns[i], axis=1)
    
        cntr += 1
    else:
        i += 1

print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# First_REC_Yards_%
# > 1 features were deleted.
# > 80 features remain.

# %%
# remove highly collinear features, keeping the feature w/strongest correlation to y-var
corr_thres = .70
drop_cntr = i = j_flag = i_flag = 0

while i < len(train_x.columns):
    j = i+1
    while j < len(train_x.columns):
        if (abs(train_x[train_x.columns[i]].corr(train_x[train_x.columns[j]])) > corr_thres):
            if abs(train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64'))) <= abs(train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64'))):
                print("deleted:", train_x.columns[i], " ", train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),
                      "\nkept:\t", train_x.columns[j], " ", train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),"\n");
                train_x = train_x.drop(train_x.columns[i], axis=1)
                x_all = x_all.drop(x_all.columns[i], axis=1)
                drop_cntr += 1
                i_flag = 1
                break
            else:
                print("deleted:", train_x.columns[j], " ", train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),
                      "\nkept:\t", train_x.columns[i], " ", train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),"\n");
                train_x = train_x.drop(train_x.columns[j], axis=1)
                x_all = x_all.drop(x_all.columns[j], axis=1)
                drop_cntr += 1
                j_flag = 1
        if j_flag == 0:
            j += 1
        j_flag = 0
    if i_flag == 0:
        i += 1
    i_flag = 0
                                                                                            
print('\033[1m' + '> ' + str(drop_cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# deleted: BOA_15%   -0.31294583486151206
# kept:	 BOA_20%   -0.35222352462167517
#
# deleted: Best_Total_Dominator   0.35174383394805186
# kept:	 BOA_20%   -0.35222352462167517
#
# deleted: BOA_20%   -0.35222352462167517
# kept:	 AVG_Total_Dominator   0.37392624527431273
#
# deleted: Career_YTMA_Dominator   0.4436028109227555
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_ADJ_YTMA   0.4485339271357052
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_ADJ_YTMA   0.46467905067402854
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: AVG_ADJ_YTMA   0.45408713376553794
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_Experience_Adjusted_ADJ_YTMA   0.41449991520336354
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_Experience_Adjusted_ADJ_YTMA   0.43922173035061635
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: AVG_Experience_Adjusted_ADJ_YTMA   0.40798130581506253
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_YTMA   0.42243119604583645
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_YTMA   0.4467168731015349
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: AVG_YTMA   0.45867651335131043
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_Experience__Adjusted_YTMA   0.40698438540513027
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_Experience__Adjusted_YTMA   0.4283567484445186
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: AVG_Experience__Adjusted_YTMA   0.45615584032201156
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_Total_Dominator   0.3753021128038515
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: AVG_Total_Dominator   0.37392624527431273
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_RushYDs/TMA   0.3468386490515217
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_Cofe_RushYDs/TMrA   0.38792445643218154
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_MS_Rush_Yards   0.3360295885751438
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_MS_Rush_Yards   0.37165276599574365
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_Ms_Rush_TDs   0.3458872484964948
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_RuAtt/GP   0.3584946794283649
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_RuAtt/GP   0.3848347929369525
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Avg_RuAtt/GP   0.38321975819370746
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_RuYd/GP   0.4219731185415976
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_RuYd/GP   0.4378343660338644
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Avg_RuYd/GP   0.4501155689644754
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_RuTd/G   0.40437467217769396
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_MS_RuATTs   0.33830905957848934
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_MS_RuATTs   0.3674377989726789
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Avg_MS_RuATTs   0.37643675646494723
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_Conf_Adjusted_YTMA   0.41787982236259724
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_Team_Adjusted_YTMA   0.4028832851114701
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_Conference_Adjusted_ADJ_YTMA   0.4270930686009248
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Best_Experience_Adjusted_YTMrA   0.38792445643218154
# kept:	 Career_ADJ_YTMA_Dominator   0.46602404953115745
#
# deleted: Last_REC_Yards_%   -0.07173246624004138
# kept:	 Best_REC_Yards_%   -0.08572480539656194
#
# deleted: Best_REC_Yards_%   -0.08572480539656194
# kept:	 AVG_REC_Yards_%   -0.09812116381256912
#
# deleted: AVG_REC_Yards_%   -0.09812116381256912
# kept:	 RUSH%_AVG   0.09812116381256913
#
# deleted: First_ADJ_YTMA   0.29016526477515364
# kept:	 First_Experience_Adjusted_ADJ_YTMA   0.306954143359847
#
# deleted: First_Experience_Adjusted_ADJ_YTMA   0.306954143359847
# kept:	 First_YTMA   0.31510134921999183
#
# deleted: First_Experience__Adjusted_YTMA   0.31380981781521206
# kept:	 First_YTMA   0.31510134921999183
#
# deleted: First_Total_Dominator   0.23605332123251804
# kept:	 First_YTMA   0.31510134921999183
#
# deleted: First_MS_Rush_Yards   0.2729888129939434
# kept:	 First_YTMA   0.31510134921999183
#
# deleted: First_Ms_Rush_TDs   0.20405048579663168
# kept:	 First_YTMA   0.31510134921999183
#
# deleted: First_MS_Rec_Yds   0.1387988007610803
# kept:	 First_Weighted_Dominator   0.170454632282898
#
# deleted: First_Weighted_Dominator   0.170454632282898
# kept:	 Avg_RecYd/GP   0.2480920177965818
#
# deleted: Best_Weighted_Dominator   0.19531093627814858
# kept:	 Last_Weighted_Dominator   0.23233626031923615
#
# deleted: Best_MS_Rec_Yds   0.21049157597922938
# kept:	 Last_Weighted_Dominator   0.23233626031923615
#
# deleted: Last_Weighted_Dominator   0.23233626031923615
# kept:	 Last_MS_Rec_Yds   0.24032917236545523
#
# deleted: Last_MS_Rec_Yds   0.24032917236545523
# kept:	 Last_Rec/GP   0.24648863664319828
#
# deleted: Best_Ms_Rush_TDs   0.29546337985658244
# kept:	 Best_RuTd/G   0.39265003024692907
#
# deleted: Best_RuTd/G   0.39265003024692907
# kept:	 Avg_RuTd/G   0.40414695732134626
#
# deleted: Best_Rec/GP   0.23428954205818622
# kept:	 Last_Rec/GP   0.24648863664319828
#
# deleted: Avg_Rec/GP   0.23064279115024594
# kept:	 Last_Rec/GP   0.24648863664319828
#
# deleted: Last_Rec/GP   0.24648863664319828
# kept:	 Best_RecYd/GP   0.2653686208972696
#
# deleted: Last_RecYd/GP   0.2601403539063019
# kept:	 Best_RecYd/GP   0.2653686208972696
#
# deleted: Avg_RecYd/GP   0.2480920177965818
# kept:	 Best_RecYd/GP   0.2653686208972696
#
# deleted: Best_RecYd/GP   0.2653686208972696
# kept:	 Best_MS_RECs   0.2704951299492816
#
# deleted: Best_RecTD/GP   0.1450512709409575
# kept:	 Last_RecTD/GP   0.1764464056667459
#
# deleted: Avg_RecTD/GP   0.15357449207100154
# kept:	 Last_RecTD/GP   0.1764464056667459
#
# deleted: Last_MS_RecTd   0.14663816346322484
# kept:	 Last_RecTD/GP   0.1764464056667459
#
# deleted: Avg_MS_RecTd   0.1336805262767878
# kept:	 Last_RecTD/GP   0.1764464056667459
#
# deleted: Best_MS_RECs   0.2704951299492816
# kept:	 Last_MS_RECs   0.2861595554090782
#
# deleted: Avg_MS_RECs   0.2817074025896421
# kept:	 Last_MS_RECs   0.2861595554090782
#
# > 66 features were deleted.
# > 14 features remain.

# %%
# manual drops

# list_to_drop = []
# cntr = 0

# for i in list_to_drop:
#     x_all = x_all.drop(i, axis=1)
#     train_x = train_x.drop(i, axis=1)
#     cntr += 1


# print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
# print('\033[1m' + '> ' + str(len(x_all.columns)) + ' features remain.' + '\033[0m')#

# %%
train_x = train_x.fillna(x_all.mean())
x_all = x_all.fillna(x_all.mean())

# %%
print(x_all.isna().sum())
# Out:
# DP                                         0
# Age_IN_DRAFT_YEAR                          0
# Career_YPTch                               0
# Career_ADJ_YTMA_Dominator                  0
# RUSH%_AVG                                  0
# First_YTMA                                 0
# Avg_RuTd/G                                 0
# Last_RecTD/GP                              0
# Last_MS_RECs                               0
# Best_MS_RecTd                              0
# Best_Pos_Opp_%                             0
# Best_TDOa_Diff_from_AVG_Total_Dominator    0
# Burst_Score                                0
# Adjusted_40_Time                           0
# dtype: int64

# %%
# print correlations
i = 0
while i < len(train_x.columns):
    corr = abs(train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')))
    print(train_x.columns[i],": {0:.2f}%".format(corr*100),sep='')
    i += 1
# Out:
# DP: 63.13%
# Age_IN_DRAFT_YEAR: 26.34%
# Career_YPTch: 7.42%
# Career_ADJ_YTMA_Dominator: 46.60%
# RUSH%_AVG: 9.79%
# First_YTMA: 31.47%
# Avg_RuTd/G: 40.41%
# Last_RecTD/GP: 17.64%
# Last_MS_RECs: 28.61%
# Best_MS_RecTd: 10.89%
# Best_Pos_Opp_%: 8.04%
# Best_TDOa_Diff_from_AVG_Total_Dominator: 27.75%
# Burst_Score: 13.66%
# Adjusted_40_Time: 9.71%

# %%
# Correlation Heatmap
plt.figure(figsize=(20, 10))
sns.heatmap(abs(train_x.join(train_y).astype('float64').corr()), annot=True)
# Out:
# <AxesSubplot:>

# %%
len(train_x.columns)
# Out:
# 14

# %%
#todo:
   #set up param_grid
   #figure out best scoring function for scorers
   #note that it is fitting to train_x and train_y, maybe do it with the stratified split instead?
   #make table pretty and post
   #get scoring metrics for resume
    
param_grid = dict(
    learning_rate=[0.01,0.05],
    n_estimators=[150,200],
    subsample=[.7],
    max_features=[10,11,13],
    max_depth=[2],
    min_samples_leaf=[5,7,10],
    min_samples_split=[10,20,30],
)
scorer_05p = make_scorer(
    mean_pinball_loss,
    alpha=.05,
    greater_is_better=False,  # maximize the negative loss
)
scorer_95p = make_scorer(
    mean_pinball_loss,
    alpha=.95,
    greater_is_better=False,  # maximize the negative loss
)

# %%
# gridsearch for 0.05 quantile
gsearch_low = GridSearchCV(
    estimator=GradientBoostingRegressor(alpha=0.05,loss='quantile'),
    param_grid=param_grid,
    scoring=scorer_05p,
    n_jobs=-1,
    cv=5)
gsearch_low.fit(train_x, np.ravel(train_y))
gsearch_low.best_params_
# Out:
# {'learning_rate': 0.01,
#  'max_depth': 2,
#  'max_features': 13,
#  'min_samples_leaf': 7,
#  'min_samples_split': 20,
#  'n_estimators': 200,
#  'subsample': 0.7}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance

feature_importance = gsearch_low.best_estimator_.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 8))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(x_all.columns)[sorted_idx])
plt.title('Feature Importance (MDI) of 5% Quantile Regressor')
fig.tight_layout()
plt.show()

# %%
# gridsearch for 0.50 quantile, which minimizes the mean absolute error (MAE)
# gsearch_median = GridSearchCV(
#     estimator=GradientBoostingRegressor(alpha=0.50,loss='quantile'),
#     param_grid=param_grid,
#     scoring='neg_mean_absolute_error',
#     n_jobs=-1,
#     cv=5)
# gsearch_median.fit(train_x, np.ravel(train_y))
# gsearch_median.best_params_

# %%
# gridsearch for 0.95 quantile
gsearch_high = GridSearchCV(
    estimator=GradientBoostingRegressor(alpha=0.95,loss='quantile'),
    param_grid=param_grid,
    scoring=scorer_95p,
    n_jobs=-1,
    cv=5)
gsearch_high.fit(train_x, np.ravel(train_y))
gsearch_high.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 2,
#  'max_features': 13,
#  'min_samples_leaf': 5,
#  'min_samples_split': 30,
#  'n_estimators': 150,
#  'subsample': 0.7}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance

feature_importance = gsearch_high.best_estimator_.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 8))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(x_all.columns)[sorted_idx])
plt.title('Feature Importance (MDI) of 95% Quantile Regressor')
fig.tight_layout()
plt.show()

# %%
low_preds = np.zeros(len(x_all))
#median_preds = np.zeros(len(x_all))
high_preds = np.zeros(len(x_all))
# average predictions over a range of seeds [0,99]
for x in range(100):
    low_preds = (low_preds + gsearch_low.predict(x_all))/2
#    median_preds = (median_preds + gsearch_median.predict(x_all))/2
    high_preds = (high_preds + gsearch_high.predict(x_all))/2
    
#output = pd.DataFrame({'5%':low_preds,'50%':median_preds,'95%':high_preds}).astype('float')
output = pd.DataFrame({'5%':low_preds, '95%':high_preds}).astype('float')
print("done")
# Out:
# done

# %%
pd.set_option('display.max_rows', 10000) 
pd.set_option('display.max_columns', 1000)

# %%
#printing results prints dataframe but takes too long to render on github
def red_background_2022(cell_value):
    highlight = 'background-color: tomato;'
    default = ''
    if cell_value == 2022:
        return highlight
    else:
        return default 
    
results = labels_all.join(y_all).join(output)
#results = labels_all.join(output)
#results = results.sort_values(by=['0.50'], ascending=False).reset_index(drop=True)
results = results.sort_values(by=['Draft_Year','95%'], ascending=False).reset_index(drop=True)
#results = results.drop('Draft Year', axis=1)
results.loc[:, "Y1-Y3_PPR_PPG"] = results["Y1-Y3_PPR_PPG"].map('{:.2f}'.format)
results["5%"] = results["5%"].map('{:.2f}'.format)
results["95%"] = results["95%"].map('{:.2f}'.format)
cm = sns.color_palette("inferno", as_cmap=True)
results1 = results.style.set_table_styles([dict(selector='th', props=[('text-align', 'center')])]).background_gradient(cmap=cm, subset=['5%','95%'],vmin=-0.99, vmax=17.07)
results1.set_properties(**{'text-align': 'center'},subset=['5%','95%','Player','School'])
results.style.background_gradient(cmap=cm, subset=['5%','95%']).applymap(red_background_2022)
# Out:
# <style type="text/css">
# #T_eff95_row0_col6, #T_eff95_row85_col7, #T_eff95_row86_col6, #T_eff95_row122_col6, #T_eff95_row174_col6, #T_eff95_row175_col6, #T_eff95_row209_col6, #T_eff95_row212_col6, #T_eff95_row500_col6, #T_eff95_row503_col6, #T_eff95_row504_col6 {
#   background-color: #d44842;
#   color: #f1f1f1;
# }
# #T_eff95_row0_col7 {
#   background-color: #fc9f07;
#   color: #000000;
# }
# #T_eff95_row1_col6, #T_eff95_row2_col6, #T_eff95_row3_col6, #T_eff95_row5_col6, #T_eff95_row36_col6, #T_eff95_row123_col6, #T_eff95_row128_col6, #T_eff95_row208_col6, #T_eff95_row295_col6, #T_eff95_row361_col6, #T_eff95_row362_col6, #T_eff95_row384_col6, #T_eff95_row423_col6, #T_eff95_row428_col6, #T_eff95_row469_col6, #T_eff95_row505_col6, #T_eff95_row515_col6, #T_eff95_row544_col6 {
#   background-color: #b63458;
#   color: #f1f1f1;
# }
# #T_eff95_row1_col7, #T_eff95_row499_col7 {
#   background-color: #ed6925;
#   color: #f1f1f1;
# }
# #T_eff95_row2_col7, #T_eff95_row19_col7, #T_eff95_row123_col7, #T_eff95_row209_col7, #T_eff95_row247_col7, #T_eff95_row378_col7 {
#   background-color: #cb4149;
#   color: #f1f1f1;
# }
# #T_eff95_row3_col7, #T_eff95_row130_col7, #T_eff95_row383_col7, #T_eff95_row506_col7 {
#   background-color: #982766;
#   color: #f1f1f1;
# }
# #T_eff95_row4_col6, #T_eff95_row251_col6, #T_eff95_row292_col6, #T_eff95_row465_col6 {
#   background-color: #f57d15;
#   color: #f1f1f1;
# }
# #T_eff95_row4_col7 {
#   background-color: #922568;
#   color: #f1f1f1;
# }
# #T_eff95_row5_col7, #T_eff95_row251_col7, #T_eff95_row296_col7, #T_eff95_row349_col7, #T_eff95_row429_col7 {
#   background-color: #7f1e6c;
#   color: #f1f1f1;
# }
# #T_eff95_row6_col6, #T_eff95_row20_col7, #T_eff95_row83_col6, #T_eff95_row242_col6, #T_eff95_row297_col6, #T_eff95_row340_col6, #T_eff95_row472_col6 {
#   background-color: #ca404a;
#   color: #f1f1f1;
# }
# #T_eff95_row6_col7, #T_eff95_row45_col7, #T_eff95_row103_col7, #T_eff95_row185_col7, #T_eff95_row186_col7, #T_eff95_row355_col7, #T_eff95_row356_col7, #T_eff95_row442_col7, #T_eff95_row443_col7, #T_eff95_row516_col7 {
#   background-color: #390963;
#   color: #f1f1f1;
# }
# #T_eff95_row7_col6, #T_eff95_row8_col6, #T_eff95_row9_col6, #T_eff95_row10_col6, #T_eff95_row11_col6, #T_eff95_row12_col6, #T_eff95_row12_col7, #T_eff95_row13_col6, #T_eff95_row15_col6, #T_eff95_row16_col6, #T_eff95_row17_col6, #T_eff95_row23_col6, #T_eff95_row28_col6, #T_eff95_row34_col6, #T_eff95_row37_col6, #T_eff95_row38_col6, #T_eff95_row39_col6, #T_eff95_row40_col6, #T_eff95_row41_col6, #T_eff95_row42_col6, #T_eff95_row44_col6, #T_eff95_row45_col6, #T_eff95_row46_col6, #T_eff95_row47_col6, #T_eff95_row48_col6, #T_eff95_row50_col6, #T_eff95_row51_col6, #T_eff95_row53_col6, #T_eff95_row54_col6, #T_eff95_row56_col6, #T_eff95_row57_col6, #T_eff95_row58_col6, #T_eff95_row59_col6, #T_eff95_row60_col6, #T_eff95_row61_col6, #T_eff95_row62_col6, #T_eff95_row63_col6, #T_eff95_row64_col6, #T_eff95_row64_col7, #T_eff95_row65_col6, #T_eff95_row66_col6, #T_eff95_row67_col6, #T_eff95_row68_col6, #T_eff95_row70_col6, #T_eff95_row71_col6, #T_eff95_row72_col6, #T_eff95_row73_col6, #T_eff95_row74_col6, #T_eff95_row75_col6, #T_eff95_row76_col6, #T_eff95_row77_col6, #T_eff95_row78_col6, #T_eff95_row79_col6, #T_eff95_row80_col6, #T_eff95_row81_col6, #T_eff95_row82_col6, #T_eff95_row89_col6, #T_eff95_row91_col6, #T_eff95_row92_col6, #T_eff95_row93_col6, #T_eff95_row95_col6, #T_eff95_row97_col6, #T_eff95_row99_col6, #T_eff95_row100_col6, #T_eff95_row101_col6, #T_eff95_row102_col6, #T_eff95_row104_col6, #T_eff95_row105_col6, #T_eff95_row107_col6, #T_eff95_row108_col6, #T_eff95_row110_col6, #T_eff95_row112_col6, #T_eff95_row113_col6, #T_eff95_row113_col7, #T_eff95_row114_col6, #T_eff95_row115_col6, #T_eff95_row116_col6, #T_eff95_row117_col6, #T_eff95_row118_col6, #T_eff95_row119_col6, #T_eff95_row120_col6, #T_eff95_row127_col6, #T_eff95_row134_col6, #T_eff95_row136_col6, #T_eff95_row137_col6, #T_eff95_row138_col6, #T_eff95_row139_col6, #T_eff95_row140_col6, #T_eff95_row141_col6, #T_eff95_row143_col6, #T_eff95_row144_col6, #T_eff95_row145_col6, #T_eff95_row146_col6, #T_eff95_row147_col6, #T_eff95_row148_col6, #T_eff95_row149_col6, #T_eff95_row150_col6, #T_eff95_row153_col6, #T_eff95_row154_col6, #T_eff95_row155_col6, #T_eff95_row157_col6, #T_eff95_row158_col6, #T_eff95_row159_col6, #T_eff95_row161_col6, #T_eff95_row162_col6, #T_eff95_row163_col6, #T_eff95_row164_col6, #T_eff95_row165_col6, #T_eff95_row166_col6, #T_eff95_row167_col6, #T_eff95_row168_col6, #T_eff95_row176_col6, #T_eff95_row177_col6, #T_eff95_row178_col6, #T_eff95_row183_col6, #T_eff95_row186_col6, #T_eff95_row189_col6, #T_eff95_row190_col6, #T_eff95_row191_col6, #T_eff95_row193_col6, #T_eff95_row195_col6, #T_eff95_row196_col6, #T_eff95_row197_col6, #T_eff95_row198_col6, #T_eff95_row199_col6, #T_eff95_row200_col6, #T_eff95_row201_col6, #T_eff95_row202_col6, #T_eff95_row203_col6, #T_eff95_row204_col6, #T_eff95_row213_col6, #T_eff95_row215_col6, #T_eff95_row220_col6, #T_eff95_row221_col6, #T_eff95_row223_col6, #T_eff95_row225_col6, #T_eff95_row226_col6, #T_eff95_row227_col6, #T_eff95_row228_col6, #T_eff95_row229_col6, #T_eff95_row230_col6, #T_eff95_row231_col6, #T_eff95_row233_col6, #T_eff95_row234_col6, #T_eff95_row236_col6, #T_eff95_row237_col6, #T_eff95_row239_col6, #T_eff95_row249_col6, #T_eff95_row250_col6, #T_eff95_row256_col6, #T_eff95_row259_col6, #T_eff95_row260_col6, #T_eff95_row261_col6, #T_eff95_row262_col6, #T_eff95_row264_col6, #T_eff95_row265_col6, #T_eff95_row266_col6, #T_eff95_row267_col6, #T_eff95_row268_col6, #T_eff95_row269_col6, #T_eff95_row272_col6, #T_eff95_row274_col6, #T_eff95_row275_col6, #T_eff95_row277_col6, #T_eff95_row278_col6, #T_eff95_row279_col6, #T_eff95_row280_col6, #T_eff95_row281_col6, #T_eff95_row282_col6, #T_eff95_row283_col6, #T_eff95_row284_col6, #T_eff95_row285_col6, #T_eff95_row286_col6, #T_eff95_row287_col6, #T_eff95_row288_col6, #T_eff95_row289_col6, #T_eff95_row290_col6, #T_eff95_row291_col6, #T_eff95_row302_col6, #T_eff95_row304_col6, #T_eff95_row305_col6, #T_eff95_row306_col6, #T_eff95_row307_col6, #T_eff95_row308_col6, #T_eff95_row310_co ...

# %%
# check the 90% interval coverage accuracy
def coverage_fraction(y, y_low, y_high):
    return np.mean(np.logical_and(y >= y_low, y <= y_high))

# %%
coverage_fraction(train_y.values.ravel(), gsearch_low.predict(train_x), gsearch_high.predict(train_x))
# Out:
# 0.9006772009029346

# %%
results.to_excel("~/Desktop/rb_quantiles.xlsx")
