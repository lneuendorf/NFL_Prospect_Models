# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import arange
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_pinball_loss

# %%
# load data
pd.set_option('display.max_rows', 10000) 
pd.set_option('display.max_columns', 1000)
df = pd.read_excel('~/nfl_dashboard/ml_models/data/rb_data.xlsx')
df.drop(['Clean_Name','DR','G_Y2','G_Y3','Y1_PPR_Pts','Pts_Y2','Pts_Y3','Y1-Y3_Total_PPR','Y1-Y3_Tot_G','Y1-Y3_PPR_PPG'], axis=1, inplace=True)
df.sort_values(by='Draft_Year', ascending=False, inplace=True, ignore_index=True)

# split data
labels_all = df.iloc[:, 0:5]
x_all = df.iloc[:, 5:-2] # all features
y_all = df.iloc[:, -1:] # all y data
train_x = df.iloc[19:, 5:-2] # features with at least 3 nfl years
train_y = df.iloc[19:, -1:] # y data with at least 3 nfl years

# %%
df.head()
# Out:
#                 Name             School      Conference  Draft_Year  \
# 0  Donald Chaney Jr.         Miami (FL)   ACC (Coastal)        2023
# 1       Jahmyr Gibbs       Georgia Tech   ACC (Coastal)        2023
# 2  Jo'quavious Marks  Mississippi State      SEC (West)        2023
# 3     Bijan Robinson              Texas          Big 12        2023
# 4    Zach Charbonnet               UCLA  Pac-12 (South)        2023
#
#   Landing_Team   DP  Age_IN_DRAFT_YEAR  BOA_15%  BOA_20%  Career_YPTch  \
# 0          NaN  300                 22      NaN      NaN      5.637363
# 1          NaN   30                 21     18.0     18.0      6.783505
# 2          NaN  300                 22     19.0     19.0      4.712025
# 3          NaN   12                 21     18.0     19.0      7.208075
# 4          NaN   55                 21     18.0     18.0      5.562500
#
#    Career_YTMA_Dominator  Career_ADJ_YTMA_Dominator  First_REC_Yards_%  \
# 0               0.460438                   0.766709           0.307527
# 1               1.568757                   2.181565           0.397117
# 2               0.939050                   1.457645           0.462069
# 3               2.138346                   2.581955           0.218020
# 4               1.593787                   1.829152           0.000000
#
#    Best_REC_Yards_%  Last_REC_Yards_%  AVG_REC_Yards_%  RUSH%_AVG  \
# 0          0.307527          0.083333         0.286550   0.713450
# 1          0.397117          0.383980         0.389058   0.610942
# 2          0.552255          0.552255         0.517126   0.482874
# 3          0.218020          0.207454         0.211547   0.788453
# 4          0.248485          0.147676         0.106966   0.893034
#
#    First_ADJ_YTMA  Best_ADJ_YTMA  Last_ADJ_YTMA  AVG_ADJ_YTMA  \
# 0        0.766709       0.766709       0.766709      0.766709
# 1        2.219908       2.219908       2.143223      2.181565
# 2        1.129161       1.457645       1.457645      1.293403
# 3        1.723324       2.581955       2.581955      2.152639
# 4        0.821267       1.829152       1.829152      1.325209
#
#    First_Experience_Adjusted_ADJ_YTMA  Best_Experience_Adjusted_ADJ_YTMA  \
# 0                            0.192294                           0.192294
# 1                            1.645494                           1.645494
# 2                            0.644920                           0.644920
# 3                            1.067514                           1.715454
# 4                            0.289553                           0.859668
#
#    Last_Experience_Adjusted_ADJ_YTMA  AVG_Experience_Adjusted_ADJ_YTMA  \
# 0                           0.192294                          0.192294
# 1                           1.621729                          1.633611
# 2                           0.637389                          0.641155
# 3                           1.715454                          1.391484
# 4                           0.859668                          0.574611
#
#    First_YTMA  Best_YTMA  Last_YTMA  AVG_YTMA  \
# 0    0.586381   0.586381   0.334495  0.460438
# 1    1.588921   1.588921   1.548593  1.568757
# 2    0.772304   0.939050   0.939050  0.855677
# 3    1.414857   2.138346   2.138346  1.776601
# 4    0.821267   1.593787   1.593787  0.976893
#
#    First_Experience__Adjusted_YTMA  Best_Experience__Adjusted_YTMA  \
# 0                        -0.111660                       -0.111660
# 1                         0.890881                        0.904157
# 2                         0.186254                        0.186254
# 3                         0.673628                        1.149867
# 4                         0.144143                        0.588251
#
#    Last_Experience__Adjusted_YTMA  AVG_Experience__Adjusted_YTMA  \
# 0                       -0.309941                      -0.210801
# 1                        0.904157                       0.897519
# 2                        0.024447                       0.105351
# 3                        1.149867                       0.911747
# 4                        0.588251                       0.170191
#
#    First_Total_Dominator  Best_Total_Dominator  Last_Total_Dominator  \
# 0               0.098011              0.098011              0.019726
# 1               0.207194              0.234335              0.234335
# 2               0.263163              0.317209              0.317209
# 3               0.172650              0.289486              0.289486
# 4               0.202366              0.230250              0.230250
#
#    AVG_Total_Dominator  First_Weighted_Dominator  Best_Weighted_Dominator  \
# 0             0.058868                  0.037508                 0.037508
# 1             0.220765                  0.143970                 0.199952
# 2             0.290186                  0.082003                 0.097875
# 3             0.231068                  0.083566                 0.114832
# 4             0.166488                  0.000000                 0.058069
#
#    Last_Weighted_Dominator  AVG_Weighted_Dominator  First_RushYDs/TMrA  \
# 0                 0.000830                0.019169            0.779661
# 1                 0.179317                0.171961            1.622575
# 2                 0.097875                0.081831            1.591837
# 3                 0.114832                0.091656            2.157766
# 4                 0.058069                0.039953            1.528421
#
#    Best_RushYDs/TMA  Last_RushYDs/TMA  AVG_RushYDs/TMrA  \
# 0          0.779661          0.779661          0.779661
# 1          1.687783          1.687783          1.655179
# 2          1.591837          1.530075          1.560956
# 3          2.985430          2.985430          2.571598
# 4          2.264940          2.264940          1.896681
#
#    First_Cofe_RushYDs/TMrA  Best_Cofe_RushYDs/TMrA  Last_Cofe_RushYDs/TMrA  \
# 0                -0.230596               -0.230596               -0.230596
# 1                 0.612318                0.746487                0.746487
# 2                 0.589444                0.589444                0.102295
# 3                 0.956174                1.373300                1.373300
# 4                 0.374038                0.721584                0.721584
#
#    AVG_Cofe_RushYDs/TMrA  First_MS_Rec_Yds  Best_MS_Rec_Yds  Last_MS_Rec_Yds  \
# 0                    NaN          0.046885         0.046885         0.001038
# 1               0.679402          0.152185         0.196368         0.196368
# 2               0.345870          0.082234         0.102074         0.102074
# 3               1.164737          0.069975         0.109057         0.109057
# 4               0.547811          0.000000         0.072587         0.072587
#
#    AVG_MS_Rec_Yds  First_MS_Rush_Yards  Best_MS_Rush_Yards  \
# 0        0.023962             0.178492            0.178492
# 1        0.174277             0.240084            0.363194
# 2        0.092154             0.595420            0.595420
# 3        0.089516             0.358125            0.470957
# 4        0.049942             0.369466            0.429057
#
#    Last_MS_Rush_Yards  AVG_MS_Rush_Yards  First_Ms_Rush_TDs  Best_Ms_Rush_TDs  \
# 0            0.027866           0.103179           0.166667          0.166667
# 1            0.363194           0.301639           0.222222          0.266667
#
#    Last_Conf_Adjusted_YTMA  Avg_Conf_Adjusted_YTMA  Best_Team_Adjusted_YTMA  \
# 0                -0.494221               -0.367154                -0.291941
# 1                 0.719878                0.741166                 0.697407
# 2                 0.050758               -0.034677                 0.011738
# 3                 1.259753                0.898222                 1.286951
# 4                 0.667396                0.124142                 0.797916
#
#    Last_Team_Adjusted_YTMA  Avg_Team_Adjusted_YTMA  \
# 0                -0.535038               -0.413490
# 1                 0.606608                0.652008
# 2                 0.011738               -0.034053
# 3                 1.286951                0.917353
# 4                 0.797916                0.185238
#
#    Best_Conference_Adjusted_ADJ_YTMA  Last_Conference_Adjusted_ADJ_YTMA  \
# 0                           0.074652                           0.074652
# 1                           1.527852                           1.461455
# 2                           0.692291                           0.692291
# 3                           1.799366                           1.799366
# 4                           1.049773                           1.049773
#
#    Avg_Conference_Adjusted_ADJ_YTMA  Best_Experience_Adjusted_YTMrA  \
# 0                          0.074652                       -0.230596
# 1                          1.494653                        0.746487
# 2                          0.522411                        0.589444
# 3                          1.370927                        1.373300
# 4                          0.584628                        0.721584
#
#    Last_Experience_Adjusted_YTMrA  Avg_Experience_Adjusted_YTMrA  \
# 0                       -0.230596                      -0.230596
# 1                        0.746487                       0.679402
# 2                        0.102295                       0.345870
# 3                        1.373300                       1.164737
# 4                        0.721584                       0.547811
#
#    Best_TDOa_Diff_from_AVG_Total_Dominator  \
# 0                                -0.113072
# 1                                 0.038352
# 2                                 0.071573
# 3                                 0.078404
# 4                                 0.033524
#
#    Last_TDOa_Diff_from_AVG_Total_Dominator  \
# 0                                -0.225910
# 1                                 0.023252
# 2                                 0.071573
# 3                                 0.078404
# 4                                -0.015386
#
#    Avg_TDOa_Diff_from_AVG_Total_Dominator  weight  height  bench  3Cone  \
# 0                               -0.169491     NaN     NaN    NaN    NaN
# 1                                0.030802     NaN     NaN    NaN    NaN
# 2                                0.061827     NaN     NaN    NaN    NaN
# 3                                0.041106     NaN     NaN    NaN    NaN
# 4                               -0.042032     NaN     NaN    NaN    NaN
#
#    shuttle  vert  broadInches  Burst_Score  Adjusted_40_Time  WaSS  G_Y1  \
# 0      NaN   NaN          NaN          NaN               NaN   NaN   NaN
# 1      NaN   NaN          NaN          NaN               NaN   NaN   NaN
# 2      NaN   NaN          NaN          NaN               NaN   NaN   NaN
# 3      NaN   NaN          NaN          NaN               NaN   NaN   NaN
# 4      NaN   NaN          NaN          NaN               NaN   NaN   NaN
#
#    Y1_PPR_PPG
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# if played under 4 games in Y1 and scored over 10 ppg, drop data from training set
df_t = train_x.join(train_y).join(df.iloc[19:,-2:-1])
df_t = df_t.drop(df_t[(df_t['G_Y1'] < 4) & (df_t['Y1_PPR_PPG'] > 10)].index)
train_x, train_y= df_t.iloc[:,:-2], df_t.iloc[:,-2:-1]

# %%
# fill missing values
train_x['BOA_15%'].fillna(value=24, inplace=True)
x_all['BOA_15%'].fillna(value=24, inplace=True)
train_x['BOA_20%'].fillna(value=24, inplace=True)
x_all['BOA_20%'].fillna(value=24, inplace=True)
train_x['WaSS'].fillna(value=train_x['WaSS'].mean(), inplace=True)
x_all['WaSS'].fillna(value=x_all['WaSS'].mean(), inplace=True)
train_x['Burst_Score'].fillna(value=train_x['Burst_Score'].mean(), inplace=True)
x_all['Burst_Score'].fillna(value=x_all['Burst_Score'].mean(), inplace=True)

# %%
x_all.isna().sum()
# Out:
# DP                                             0
# Age_IN_DRAFT_YEAR                              0
# BOA_15%                                        0
# BOA_20%                                        0
# Career_YPTch                                   0
# Career_YTMA_Dominator                          0
# Career_ADJ_YTMA_Dominator                      0
# First_REC_Yards_%                              2
# Best_REC_Yards_%                               0
# Last_REC_Yards_%                               0
# AVG_REC_Yards_%                                2
# RUSH%_AVG                                      2
# First_ADJ_YTMA                                 0
# Best_ADJ_YTMA                                  0
# Last_ADJ_YTMA                                  0
# AVG_ADJ_YTMA                                   0
# First_Experience_Adjusted_ADJ_YTMA             0
# Best_Experience_Adjusted_ADJ_YTMA              0
# Last_Experience_Adjusted_ADJ_YTMA              0
# AVG_Experience_Adjusted_ADJ_YTMA               0
# First_YTMA                                     2
# Best_YTMA                                      0
# Last_YTMA                                      0
# AVG_YTMA                                       4
# First_Experience__Adjusted_YTMA                0
# Best_Experience__Adjusted_YTMA                 0
# Last_Experience__Adjusted_YTMA                 0
# AVG_Experience__Adjusted_YTMA                  0
# First_Total_Dominator                          0
# Best_Total_Dominator                           0
# Last_Total_Dominator                           0
# AVG_Total_Dominator                            4
# First_Weighted_Dominator                       2
# Best_Weighted_Dominator                        0
# Last_Weighted_Dominator                        2
# AVG_Weighted_Dominator                        54
# First_RushYDs/TMrA                            26
# Best_RushYDs/TMA                               0
# Last_RushYDs/TMA                              26
# AVG_RushYDs/TMrA                              35
# First_Cofe_RushYDs/TMrA                       30
# Best_Cofe_RushYDs/TMrA                         0
# Last_Cofe_RushYDs/TMrA                        30
# AVG_Cofe_RushYDs/TMrA                        147
# First_MS_Rec_Yds                               2
# Best_MS_Rec_Yds                                0
# Last_MS_Rec_Yds                                2
# AVG_MS_Rec_Yds                                54
# First_MS_Rush_Yards                            2
# Best_MS_Rush_Yards                             0
# Last_MS_Rush_Yards                             2
# AVG_MS_Rush_Yards                             10
# First_Ms_Rush_TDs                              2
# Best_Ms_Rush_TDs                               0
# Last_Ms_Rush_TDs                               2
# AVG_Ms_Rush_TDs                               22
# YTMpA_Over_Conference_RB1_AVG_(best_year)     19
# Best_RuAtt/GP                                  0
# Last_RuAtt/GP                                  0
# Avg_RuAtt/GP                                   0
# Best_RuYd/GP                                   0
# Last_RuYd/GP                                   0
# Avg_RuYd/GP                                    0
# Best_RuTd/G                                    0
# Last_RuTd/G                                    0
# Avg_RuTd/G                                     0
# Best_MS_RuATTs                                 0
# Last_MS_RuATTs                                 2
# Avg_MS_RuATTs                                  2
# Best_Rec/GP                                    0
# Last_Rec/GP                                    0
# Avg_Rec/GP                                     0
# Best_RecYd/GP                                  0
# Last_RecYd/GP                                  0
# Avg_RecYd/GP                                   0
# Best_RecTD/GP                                  0
# Last_RecTD/GP                                  0
# Avg_RecTD/GP                                   0
# Best_MS_RECs                                   0
# Last_MS_RECs                                   2
# Avg_MS_RECs                                    2
# Best_MS_RecTd                                  0
# Last_MS_RecTd                                  2
# Avg_MS_RecTd                                   2
# Best_Pos_Opp_%                                 0
# Last_Pos_Opp_%                                19
# Avg_Pos_Opp_%                                 19
# Best_Conf_Adjusted_YTMA                        0
# Last_Conf_Adjusted_YTMA                       23
# Avg_Conf_Adjusted_YTMA                        23
# Best_Team_Adjusted_YTMA                        0
# Last_Team_Adjusted_YTMA                       29
# Avg_Team_Adjusted_YTMA                        29
# Best_Conference_Adjusted_ADJ_YTMA              0
# Last_Conference_Adjusted_ADJ_YTMA             25
# Avg_Conference_Adjusted_ADJ_YTMA              24
# Best_Experience_Adjusted_YTMrA                 0
# Last_Experience_Adjusted_YTMrA                31
# Avg_Experience_Adjusted_YTMrA                 30
# Best_TDOa_Diff_from_AVG_Total_Dominator        0
# Last_TDOa_Diff_from_AVG_Total_Dominator       11
# Avg_TDOa_Diff_from_AVG_Total_Dominator        10
# weight                                        74
# height                                       206
# bench                                        285
# 3Cone                                        373
# shuttle                                      362
# vert                                         252
# broadInches                                  262
# Burst_Score                                    0
# Adjusted_40_Time                             112
# WaSS                                           0
# dtype: int64

# %%
missing_threshold = .01
cntr = i = 0

while i < len(train_x.columns):
    if((train_x[train_x.columns[i]].isnull().sum()/len(train_x.index)) > missing_threshold):
        print(train_x.columns[i])
        train_x = train_x.drop(train_x.columns[i], axis=1)
        x_all = x_all.drop(x_all.columns[i], axis=1)
    
        cntr += 1
    else:
        i += 1

print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# AVG_Weighted_Dominator
# First_RushYDs/TMrA
# Last_RushYDs/TMA
# AVG_RushYDs/TMrA
# First_Cofe_RushYDs/TMrA
# Last_Cofe_RushYDs/TMrA
# AVG_Cofe_RushYDs/TMrA
# AVG_MS_Rec_Yds
# AVG_MS_Rush_Yards
# AVG_Ms_Rush_TDs
# YTMpA_Over_Conference_RB1_AVG_(best_year)
# Last_Pos_Opp_%
# Avg_Pos_Opp_%
# Last_Conf_Adjusted_YTMA
# Avg_Conf_Adjusted_YTMA
# Last_Team_Adjusted_YTMA
# Avg_Team_Adjusted_YTMA
# Last_Conference_Adjusted_ADJ_YTMA
# Avg_Conference_Adjusted_ADJ_YTMA
# Last_Experience_Adjusted_YTMrA
# Avg_Experience_Adjusted_YTMrA
# Last_TDOa_Diff_from_AVG_Total_Dominator
# Avg_TDOa_Diff_from_AVG_Total_Dominator
# weight
# height
# bench
# 3Cone
# shuttle
# vert
# broadInches
# Adjusted_40_Time
# > 31 features were deleted.
# > 81 features remain.

# %%
# drop features with low correlation
corr_threshold = .05
cntr = i = 0

while i < len(train_x.columns):
    if(abs(train_x[train_x.columns[i]].corr(train_y[train_y.columns[0]])) < corr_threshold):
        print(train_x.columns[i])
        train_x = train_x.drop(train_x.columns[i], axis=1)
        x_all = x_all.drop(x_all.columns[i], axis=1)
    
        cntr += 1
    else:
        i += 1

print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# First_REC_Yards_%
# > 1 features were deleted.
# > 80 features remain.

# %%
# remove highly collinear features, keeping the feature w/strongest correlation to y-var
corr_thres = .70
drop_cntr = i = j_flag = i_flag = 0

while i < len(train_x.columns):
    j = i+1
    while j < len(train_x.columns):
        if (abs(train_x[train_x.columns[i]].corr(train_x[train_x.columns[j]])) > corr_thres):
            if abs(train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64'))) <= abs(train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64'))):
                print("deleted:", train_x.columns[i], " ", train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),
                      "\nkept:\t", train_x.columns[j], " ", train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),"\n");
                train_x = train_x.drop(train_x.columns[i], axis=1)
                x_all = x_all.drop(x_all.columns[i], axis=1)
                drop_cntr += 1
                i_flag = 1
                break
            else:
                print("deleted:", train_x.columns[j], " ", train_x[train_x.columns[j]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),
                      "\nkept:\t", train_x.columns[i], " ", train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')),"\n");
                train_x = train_x.drop(train_x.columns[j], axis=1)
                x_all = x_all.drop(x_all.columns[j], axis=1)
                drop_cntr += 1
                j_flag = 1
        if j_flag == 0:
            j += 1
        j_flag = 0
    if i_flag == 0:
        i += 1
    i_flag = 0
                                                                                            
print('\033[1m' + '> ' + str(drop_cntr) + ' features were deleted.' + '\033[0m')
print('\033[1m' + '> ' + str(len(train_x.columns)) + ' features remain.' + '\033[0m')
# Out:
# deleted: BOA_15%   -0.24621132738188425
# kept:	 BOA_20%   -0.28727606926197796
#
# deleted: BOA_20%   -0.28727606926197796
# kept:	 Best_Total_Dominator   0.2989765313071393
#
# deleted: Career_YTMA_Dominator   0.39076898213558514
# kept:	 Career_ADJ_YTMA_Dominator   0.4049047606366904
#
# deleted: Best_ADJ_YTMA   0.39114411405405325
# kept:	 Career_ADJ_YTMA_Dominator   0.4049047606366904
#
# deleted: Last_ADJ_YTMA   0.4025351845443671
# kept:	 Career_ADJ_YTMA_Dominator   0.4049047606366904
#
# deleted: AVG_ADJ_YTMA   0.39201271981147706
# kept:	 Career_ADJ_YTMA_Dominator   0.4049047606366904
#
# deleted: Best_Experience_Adjusted_ADJ_YTMA   0.3591813345649382
# kept:	 Career_ADJ_YTMA_Dominator   0.4049047606366904
#
# deleted: Last_Experience_Adjusted_ADJ_YTMA   0.3817734617086084
# kept:	 Career_ADJ_YTMA_Dominator   0.4049047606366904
#
# deleted: AVG_Experience_Adjusted_ADJ_YTMA   0.3456185386553306
# kept:	 Career_ADJ_YTMA_Dominator   0.4049047606366904
#
# deleted: Best_YTMA   0.3720927088898842
# kept:	 Career_ADJ_YTMA_Dominator   0.4049047606366904
#
# deleted: Last_YTMA   0.3906675636339341
# kept:	 Career_ADJ_YTMA_Dominator   0.4049047606366904
#
# deleted: Career_ADJ_YTMA_Dominator   0.4049047606366904
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_REC_Yards_%   -0.06077910280377549
# kept:	 Last_REC_Yards_%   -0.06692940687474795
#
# deleted: AVG_REC_Yards_%   -0.06677680559647846
# kept:	 Last_REC_Yards_%   -0.06692940687474795
#
# deleted: Last_REC_Yards_%   -0.06692940687474795
# kept:	 RUSH%_AVG   0.06839411605806524
#
# deleted: First_ADJ_YTMA   0.22546216917880552
# kept:	 First_Experience_Adjusted_ADJ_YTMA   0.24011370177356667
#
# deleted: First_Experience_Adjusted_ADJ_YTMA   0.24011370177356667
# kept:	 First_YTMA   0.24430980935856522
#
# deleted: First_Experience__Adjusted_YTMA   0.24384819546432598
# kept:	 First_YTMA   0.24430980935856522
#
# deleted: First_Total_Dominator   0.17302082582743464
# kept:	 First_YTMA   0.24430980935856522
#
# deleted: First_MS_Rush_Yards   0.19821739009491204
# kept:	 First_YTMA   0.24430980935856522
#
# deleted: First_Ms_Rush_TDs   0.14465811843875362
# kept:	 First_YTMA   0.24430980935856522
#
# deleted: Best_Experience__Adjusted_YTMA   0.3563858253728069
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Last_Experience__Adjusted_YTMA   0.3756422413731234
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: AVG_Experience__Adjusted_YTMA   0.3965851635900838
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_Total_Dominator   0.2989765313071393
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: AVG_Total_Dominator   0.3326883269600888
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_Cofe_RushYDs/TMrA   0.32348739497451773
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_MS_Rush_Yards   0.28090244662656005
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_RuAtt/GP   0.30534926457427547
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Last_RuAtt/GP   0.340043473062693
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Avg_RuAtt/GP   0.3210083910661781
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_RuYd/GP   0.3640672794270933
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Last_RuYd/GP   0.3903273731834562
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Avg_RuYd/GP   0.3858301672937237
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_RuTd/G   0.366758973721383
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Avg_RuTd/G   0.36715399361413154
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_MS_RuATTs   0.28053388324172407
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Avg_MS_RuATTs   0.3180124905320892
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_Conf_Adjusted_YTMA   0.36942487861613676
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_Team_Adjusted_YTMA   0.3563345985135546
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_Conference_Adjusted_ADJ_YTMA   0.37803177003886995
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Best_Experience_Adjusted_YTMrA   0.32348739497451773
# kept:	 AVG_YTMA   0.4072367763142807
#
# deleted: Last_MS_Rush_Yards   0.32553034757507354
# kept:	 Last_Total_Dominator   0.33310530846290654
#
# deleted: Best_Ms_Rush_TDs   0.2643381699156374
# kept:	 Last_Total_Dominator   0.33310530846290654
#
# deleted: Last_Ms_Rush_TDs   0.3157284224946518
# kept:	 Last_Total_Dominator   0.33310530846290654
#
# deleted: Last_Total_Dominator   0.33310530846290654
# kept:	 Last_RuTd/G   0.3930496197177328
#
# deleted: First_MS_Rec_Yds   0.13669956176381842
# kept:	 First_Weighted_Dominator   0.15612517139682222
#
# deleted: First_Weighted_Dominator   0.15612517139682222
# kept:	 Avg_RecYd/GP   0.2236684105886966
#
# deleted: Best_Weighted_Dominator   0.17552977736849143
# kept:	 Last_Weighted_Dominator   0.1958476975631451
#
# deleted: Best_MS_Rec_Yds   0.19398271269099007
# kept:	 Last_Weighted_Dominator   0.1958476975631451
#
# deleted: Last_Weighted_Dominator   0.1958476975631451
# kept:	 Last_MS_Rec_Yds   0.2073941892571981
#
# deleted: Last_Rec/GP   0.20173264020345724
# kept:	 Last_MS_Rec_Yds   0.2073941892571981
#
# deleted: Last_MS_Rec_Yds   0.2073941892571981
# kept:	 Best_RecYd/GP   0.22089553835684886
#
# deleted: Best_Rec/GP   0.18249892708653626
# kept:	 Avg_Rec/GP   0.19147975448844767
#
# deleted: Avg_Rec/GP   0.19147975448844767
# kept:	 Best_RecYd/GP   0.22089553835684886
#
# deleted: Best_RecYd/GP   0.22089553835684886
# kept:	 Last_RecYd/GP   0.2274306701674496
#
# deleted: Avg_RecYd/GP   0.2236684105886966
# kept:	 Last_RecYd/GP   0.2274306701674496
#
# deleted: Last_MS_RECs   0.21470632400513673
# kept:	 Last_RecYd/GP   0.2274306701674496
#
# deleted: Best_RecTD/GP   0.12248122309976989
# kept:	 Last_RecTD/GP   0.14967503158075224
#
# deleted: Avg_RecTD/GP   0.13456985993723863
# kept:	 Last_RecTD/GP   0.14967503158075224
#
# deleted: Last_MS_RecTd   0.11056582994642868
# kept:	 Last_RecTD/GP   0.14967503158075224
#
# deleted: Avg_MS_RecTd   0.1092796072956883
# kept:	 Last_RecTD/GP   0.14967503158075224
#
# deleted: Best_MS_RECs   0.20214063425105372
# kept:	 Avg_MS_RECs   0.22325684172294477
#
# > 63 features were deleted.
# > 17 features remain.

# %%
# manual drops

# list_to_drop = []
# cntr = 0

# for i in list_to_drop:
#     x_all = x_all.drop(i, axis=1)
#     train_x = train_x.drop(i, axis=1)
#     cntr += 1


# print('\033[1m' + '> ' + str(cntr) + ' features were deleted.' + '\033[0m')
# print('\033[1m' + '> ' + str(len(x_all.columns)) + ' features remain.' + '\033[0m')#

# %%
train_x = train_x.fillna(x_all.mean())
x_all = x_all.fillna(x_all.mean())

# %%
print(x_all.isna().sum())
# Out:
# DP                                         0
# Age_IN_DRAFT_YEAR                          0
# Career_YPTch                               0
# RUSH%_AVG                                  0
# First_YTMA                                 0
# AVG_YTMA                                   0
# Best_RushYDs/TMA                           0
# Last_RuTd/G                                0
# Last_MS_RuATTs                             0
# Last_RecYd/GP                              0
# Last_RecTD/GP                              0
# Avg_MS_RECs                                0
# Best_MS_RecTd                              0
# Best_Pos_Opp_%                             0
# Best_TDOa_Diff_from_AVG_Total_Dominator    0
# Burst_Score                                0
# WaSS                                       0
# dtype: int64

# %%
# print correlations
i = 0
while i < len(train_x.columns):
    corr = abs(train_x[train_x.columns[i]].astype('float64').corr(train_y[train_y.columns[0]].astype('float64')))
    print(train_x.columns[i],": {0:.2f}%".format(corr*100),sep='')
    i += 1
# Out:
# DP: 60.62%
# Age_IN_DRAFT_YEAR: 18.97%
# Career_YPTch: 9.98%
# RUSH%_AVG: 6.83%
# First_YTMA: 24.40%
# AVG_YTMA: 40.63%
# Best_RushYDs/TMA: 29.69%
# Last_RuTd/G: 39.30%
# Last_MS_RuATTs: 32.02%
# Last_RecYd/GP: 22.74%
# Last_RecTD/GP: 14.97%
# Avg_MS_RECs: 22.30%
# Best_MS_RecTd: 8.49%
# Best_Pos_Opp_%: 7.64%
# Best_TDOa_Diff_from_AVG_Total_Dominator: 24.72%
# Burst_Score: 11.83%
# WaSS: 25.81%

# %%
# Correlation Heatmap
plt.figure(figsize=(20, 10))
sns.heatmap(abs(train_x.join(train_y).astype('float64').corr()), annot=True)
# Out:
# <AxesSubplot:>

# %%
len(train_x.columns)
# Out:
# 17

# %%
#todo:
   #set up param_grid
   #figure out best scoring function for scorers
   #note that it is fitting to train_x and train_y, maybe do it with the stratified split instead?
   #make table pretty and post
   #get scoring metrics for resume
    
param_grid = dict(
    learning_rate=[0.01,0.05],
    n_estimators=[150,200,250,300],
    subsample=[.7],
    max_features=[10,13,15,17],
    max_depth=[2],
    min_samples_leaf=[5,7,10],
    min_samples_split=[10,20,30],
)
scorer_05p = make_scorer(
    mean_pinball_loss,
    alpha=.05,
    greater_is_better=False,  # maximize the negative loss
)
scorer_95p = make_scorer(
    mean_pinball_loss,
    alpha=.95,
    greater_is_better=False,  # maximize the negative loss
)

# %%
# gridsearch for 0.05 quantile
gsearch_low = GridSearchCV(
    estimator=GradientBoostingRegressor(alpha=0.05,loss='quantile'),
    param_grid=param_grid,
    scoring=scorer_05p,
    n_jobs=-1,
    cv=5)
gsearch_low.fit(train_x, np.ravel(train_y))
gsearch_low.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 2,
#  'max_features': 17,
#  'min_samples_leaf': 7,
#  'min_samples_split': 10,
#  'n_estimators': 250,
#  'subsample': 0.7}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance

feature_importance = gsearch_low.best_estimator_.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 8))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(x_all.columns)[sorted_idx])
plt.title('Feature Importance (MDI) of 5% Quantile Regressor')
fig.tight_layout()
plt.show()

# %%
# gridsearch for 0.50 quantile, which minimizes the mean absolute error (MAE)
# gsearch_median = GridSearchCV(
#     estimator=GradientBoostingRegressor(alpha=0.50,loss='quantile'),
#     param_grid=param_grid,
#     scoring='neg_mean_absolute_error',
#     n_jobs=-1,
#     cv=5)
# gsearch_median.fit(train_x, np.ravel(train_y))
# gsearch_median.best_params_

# %%
# gridsearch for 0.95 quantile
gsearch_high = GridSearchCV(
    estimator=GradientBoostingRegressor(alpha=0.95,loss='quantile'),
    param_grid=param_grid,
    scoring=scorer_95p,
    n_jobs=-1,
    cv=5)
gsearch_high.fit(train_x, np.ravel(train_y))
gsearch_high.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 2,
#  'max_features': 15,
#  'min_samples_leaf': 10,
#  'min_samples_split': 30,
#  'n_estimators': 150,
#  'subsample': 0.7}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance

feature_importance = gsearch_high.best_estimator_.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 8))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(x_all.columns)[sorted_idx])
plt.title('Feature Importance (MDI) of 95% Quantile Regressor')
fig.tight_layout()
plt.show()

# %%
low_preds = np.zeros(len(x_all))
#median_preds = np.zeros(len(x_all))
high_preds = np.zeros(len(x_all))
# average predictions over a range of seeds [0,99]
for x in range(100):
    low_preds = (low_preds + gsearch_low.predict(x_all))/2
#    median_preds = (median_preds + gsearch_median.predict(x_all))/2
    high_preds = (high_preds + gsearch_high.predict(x_all))/2
    
#output = pd.DataFrame({'5%':low_preds,'50%':median_preds,'95%':high_preds}).astype('float')
output = pd.DataFrame({'5%':low_preds, '95%':high_preds}).astype('float')
print("done")
# Out:
# done

# %%
pd.set_option('display.max_rows', 10000) 
pd.set_option('display.max_columns', 1000)

# %%
#printing results prints dataframe but takes too long to render on github
def red_background_2022(cell_value):
    highlight = 'background-color: tomato;'
    default = ''
    if cell_value == 2022:
        return highlight
    else:
        return default 
    
results = labels_all.join(y_all).join(output)
#results = labels_all.join(output)
#results = results.sort_values(by=['0.50'], ascending=False).reset_index(drop=True)
results = results.sort_values(by=['Draft_Year','95%'], ascending=False).reset_index(drop=True)
#results = results.drop('Draft Year', axis=1)
results.loc[:, "Y1_PPR_PPG"] = results["Y1_PPR_PPG"].map('{:.2f}'.format)
results["5%"] = results["5%"].map('{:.2f}'.format)
results["95%"] = results["95%"].map('{:.2f}'.format)
cm = sns.color_palette("inferno", as_cmap=True)
results1 = results.style.set_table_styles([dict(selector='th', props=[('text-align', 'center')])]).background_gradient(cmap=cm, subset=['5%','95%'],vmin=-0.99, vmax=17.07)
results1.set_properties(**{'text-align': 'center'},subset=['5%','95%','Player','School'])
results.style.background_gradient(cmap=cm, subset=['5%','95%']).applymap(red_background_2022)
# Out:
# <style type="text/css">
# #T_79d1d_row0_col6, #T_79d1d_row2_col6, #T_79d1d_row6_col6, #T_79d1d_row24_col6, #T_79d1d_row82_col6, #T_79d1d_row86_col6, #T_79d1d_row88_col6, #T_79d1d_row89_col6, #T_79d1d_row91_col6, #T_79d1d_row127_col6, #T_79d1d_row132_col6, #T_79d1d_row168_col6, #T_79d1d_row170_col6, #T_79d1d_row206_col6, #T_79d1d_row208_col6, #T_79d1d_row216_col6, #T_79d1d_